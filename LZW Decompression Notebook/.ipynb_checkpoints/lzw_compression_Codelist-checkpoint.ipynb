# %%
from PIL import Image
from IPython.display import display
from array import array
#resources:
#https://giflib.sourceforge.net/whatsinagif/index.html
#https://github.com/qalle2/pygif
#https://bitbanksoftware.blogspot.com/2020/07/a-low-memory-gif-decoder.html

# %%
def ByteArrayReverse(Barr):
    l = list(Barr)
    l = l[::-1]
    return bytearray(l)
    
def get_CodeValue(Code,codeTable,byteTable,ColorTableLen):
    if Code < ColorTableLen:
        return Code.to_bytes(1)
    else:
        newCode = Code
        outList = []
        while newCode > ColorTableLen:
            index = newCode-(ColorTableLen+2)
            newCode = codeTable[index]
            outList.append(byteTable[index])
        outList.append(newCode)
        outList = outList[::-1]
        return bytearray(outList)

def lzw_Decompress(src,LZW_Min_Code):
    ColorTableLen = 2**LZW_Min_Code
    #print('ColorTableLen:',ColorTableLen)
    #print('LZW_Min_Code:',LZW_Min_Code)
    ClearCode = ColorTableLen
    ImgEndCode = ColorTableLen + 1
    CodeLen = LZW_Min_Code+1
    lastCode = 0
    K = 0
    Code = None
    Codekey = None
    indexStream = bytearray()
    datablock = bytearray(256)
    datablockIndex = 0
    codeTable = array('h')
    byteTable = bytearray(4096)
    byte = 0
    BitIndex = 0
    newTableIndex = ImgEndCode + 1
    ByteCount = 0
    BlockN = 0
    FirstCodeFlag = False
    ZeroBlockLenFlag = False
    while True:       
        Code = bytearray(CodeLen//8+1)
        #print('bc:',ByteCount,' ',end='')
        print('['+str(newTableIndex)+']',end="")
        print('('+str(CodeLen)+')',end="")
        print('|'+str(BitIndex)+'|',end="")
        for i in range(CodeLen):   
            if ByteCount == 0:
                ByteCount = src.read(1)[0]
                datablock = src.read(ByteCount)
                datablockIndex = 0
                #print("BlockN: ",BlockN,"BlockLen: ",ByteCount)
                if ByteCount == 0:
                    ZeroBlockLenFlag = True
                    break
                BlockN += 1
                            
            if BitIndex == 0:
                byte = datablock[datablockIndex]
                datablockIndex += 1
                ByteCount -= 1

            bit = (byte >> BitIndex) & 1
            if bit:
                Code[i//8] = Code[i//8] | 1<<i%8
            BitIndex += 1
            if BitIndex == 8:
                BitIndex = 0
        if ZeroBlockLenFlag:
            break
        print(' ',end="")
        binary_string = ''.join(f'{b:08b}' for b in bytearray([Code[-1]]))
        print(binary_string,' ',end="")
        binary_string = ''.join(f'{b:08b}' for b in bytearray([Code[0]]))
        print(binary_string,' ',end="")
        
        CodeKey = int.from_bytes(Code,'little')
        print(' ',end="")
        print(CodeKey,end="")
        print(' -> ',end="")
        #print('')
        if CodeKey == ClearCode:
            print('Clear Code - Initializing codeTable')
            codeTable = array('h')
            byteTable = bytearray(4096)
            newTableIndex = ImgEndCode+1
            FirstCodeFlag = False
            CodeLen = LZW_Min_Code+1         
        elif CodeKey == ImgEndCode:
            print('Image End Code - Decoding Complete')
            break
        else:
            if not FirstCodeFlag:
                print('First Code - Appending to indexStream')
                indexStream += bytearray(get_CodeValue(CodeKey,codeTable,byteTable,ColorTableLen))
                FirstCodeFlag = True
            else:
                if (CodeKey < newTableIndex):
                    codearr = get_CodeValue(CodeKey,codeTable,byteTable,ColorTableLen)
                    indexStream += codearr
                    K = codearr[0]
                    print('Found adding to stream -',CodeKey,codearr)
                else:
                    lastcodearr = get_CodeValue(lastCode,codeTable,byteTable,ColorTableLen)
                    K = lastcodearr[0]
                    indexStream += lastcodearr + bytearray([K])
                    print('Not Found adding to stream-',lastCode,lastcodearr + bytearray([K]))

                #codeTable[newTableIndex] = bytearray(get_CodeValue(lastCode,codeTable,ColorTableLen)) + bytearray([K])
                #codeTable.append((lastCode, bytearray([K])))
                codeTable.append(lastCode)
                byteTable[newTableIndex] = K
                if newTableIndex >= 2**CodeLen-1:
                    #print('TableIndex maxed out! ',newTableIndex)
                    #print('Increased to: ',2**(CodeLen+1)-1)
                    if CodeLen < 12:
                        CodeLen += 1
                    
                newTableIndex += 1
        lastCode = CodeKey
    print("CodeTable len: ",len(codeTable))
    return indexStream

def blit(arr,callback,startPos,frameSize,ColorTable):
    scr_y = startPos[1]
    count = 0
    for i,byte in enumerate(arr):
        scr_x = i%frameSize[0] + startPos[0]
        if scr_x == startPos[0] and i != 0:
             scr_y+= 1
        callback(scr_x,scr_y,ColorTable[byte])


def TestImage(ImagePath,ColorTablePath,frameSize,min_code):
    ColorTable = []
    newColorTable = []
    
    with open(ColorTablePath, 'r') as file:
        ColorTable = [tuple(line.strip().replace('(','').replace(')','').split(", ")) for line in file.readlines()]
        
    for color in ColorTable:
        tup = (int(color[0]),int(color[1]),int(color[2]))
        newColorTable.append(tup)
    ColorTable = newColorTable
    
    src = open(ImagePath, "rb")
    
    decompressed = lzw_Decompress(src,min_code)
    src.close()
    # Create a blank white RGB image
    img = Image.new('RGB', frameSize, color='white')
    def setPixel(x,y,color):
        px = img.load()
        px[x,y] = color
    blit(decompressed,setPixel,(0,0),frameSize,ColorTable)
    display(img)

# %%
TestImage('jake(240x240).bin','jake(240x240)-ColorTable.txt',(240,240),8)
# Out:
# [258](9)|0| 00000001  00000000   256 -> Clear Code - Initializing codeTable
# [258](9)|1| 00000000  00010111   23 -> First Code - Appending to indexStream
# [258](9)|2| 00000001  00000010   258 -> Not Found adding to stream- 23 b'\x17\x17'
# [259](9)|3| 00000001  00000011   259 -> Not Found adding to stream- 258 bytearray(b'\x17\x00\x17')
# [260](9)|4| 00000000  00010111   23 -> Found adding to stream - 23 b'\x17'
# [261](9)|5| 00000000  10110000   176 -> Found adding to stream - 176 b'\xb0'
# [262](9)|6| 00000000  10110000   176 -> Found adding to stream - 176 b'\xb0'
# [263](9)|7| 00000001  00000100   260 -> Found adding to stream - 260 bytearray(b'\x17\x00\x17\x17')
# [264](9)|0| 00000000  10000100   132 -> Found adding to stream - 132 b'\x84'
# [265](9)|1| 00000001  00000100   260 -> Found adding to stream - 260 bytearray(b'\x17\x00\x17\x17')
# [266](9)|2| 00000001  00001010   266 -> Not Found adding to stream- 260 bytearray(b'\x17\x00\x17\x17\x17')
# [267](9)|3| 00000001  00001011   267 -> Not Found adding to stream- 266 bytearray(b'\x17\x00\x17\x17\x17\x17')
# [268](9)|4| 00000001  00001100   268 -> Not Found adding to stream- 267 bytearray(b'\x17\x00\x17\x17\x17\x17\x17')
# [269](9)|5| 00000001  00001101   269 -> Not Found adding to stream- 268 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17')
# [270](9)|6| 00000001  00001110   270 -> Not Found adding to stream- 269 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17')
# [271](9)|7| 00000000  00010111   23 -> Found adding to stream - 23 b'\x17'
# [272](9)|0| 00000000  10000100   132 -> Found adding to stream - 132 b'\x84'
# [273](9)|1| 00000000  01111100   124 -> Found adding to stream - 124 b'|'
# [274](9)|2| 00000000  01000100   68 -> Found adding to stream - 68 b'D'
# [275](9)|3| 00000000  01010001   81 -> Found adding to stream - 81 b'Q'
# [276](9)|4| 00000000  01010001   81 -> Found adding to stream - 81 b'Q'
# [277](9)|5| 00000000  00001000   8 -> Found adding to stream - 8 b'\x08'
# [278](9)|6| 00000000  00001000   8 -> Found adding to stream - 8 b'\x08'
# [279](9)|7| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [280](9)|0| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [281](9)|1| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [282](9)|2| 00000001  00010110   278 -> Found adding to stream - 278 bytearray(b'\x08\x00')
# [283](9)|3| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [284](9)|4| 00000001  00011100   284 -> Not Found adding to stream- 24 b'\x18\x18'
# [285](9)|5| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [286](9)|6| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [287](9)|7| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [288](9)|0| 00000000  00101100   44 -> Found adding to stream - 44 b','
# [289](9)|1| 00000000  00110001   49 -> Found adding to stream - 49 b'1'
# [290](9)|2| 00000000  00110001   49 -> Found adding to stream - 49 b'1'
# [291](9)|3| 00000000  01000100   68 -> Found adding to stream - 68 b'D'
# [292](9)|4| 00000000  01000100   68 -> Found adding to stream - 68 b'D'
# [293](9)|5| 00000000  01111100   124 -> Found adding to stream - 124 b'|'
# [294](9)|6| 00000001  00001001   265 -> Found adding to stream - 265 bytearray(b'\x84\x00')
# [295](9)|7| 00000001  00000100   260 -> Found adding to stream - 260 bytearray(b'\x17\x00\x17\x17')
# [296](9)|0| 00000000  10110000   176 -> Found adding to stream - 176 b'\xb0'
# [297](9)|1| 00000000  11101001   233 -> Found adding to stream - 233 b'\xe9'
# [298](9)|2| 00000000  01111011   123 -> Found adding to stream - 123 b'{'
# [299](9)|3| 00000000  00000100   4 -> Found adding to stream - 4 b'\x04'
# [300](9)|4| 00000000  10110101   181 -> Found adding to stream - 181 b'\xb5'
# [301](9)|5| 00000000  00111111   63 -> Found adding to stream - 63 b'?'
# [302](9)|6| 00000000  11101000   232 -> Found adding to stream - 232 b'\xe8'
# [303](9)|7| 00000000  01111010   122 -> Found adding to stream - 122 b'z'
# [304](9)|0| 00000000  10110101   181 -> Found adding to stream - 181 b'\xb5'
# [305](9)|1| 00000000  10101101   173 -> Found adding to stream - 173 b'\xad'
# [306](9)|2| 00000000  01011100   92 -> Found adding to stream - 92 b'\\'
# [307](9)|3| 00000000  00110110   54 -> Found adding to stream - 54 b'6'
# [308](9)|4| 00000001  00000110   262 -> Found adding to stream - 262 bytearray(b'\xb0\x00')
# [309](9)|5| 00000001  00001101   269 -> Found adding to stream - 269 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17')
# [310](9)|6| 00000000  10000100   132 -> Found adding to stream - 132 b'\x84'
# [311](9)|7| 00000001  00110111   311 -> Not Found adding to stream- 132 b'\x84\x84'
# [312](9)|0| 00000001  00111000   312 -> Not Found adding to stream- 311 bytearray(b'\x84\x00\x84')
# [313](9)|1| 00000001  00111001   313 -> Not Found adding to stream- 312 bytearray(b'\x84\x00\x84\x84')
# [314](9)|2| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'Q\x00')
# [315](9)|3| 00000000  01111100   124 -> Found adding to stream - 124 b'|'
# [316](9)|4| 00000001  00111100   316 -> Not Found adding to stream- 124 b'||'
# [317](9)|5| 00000000  01010001   81 -> Found adding to stream - 81 b'Q'
# [318](9)|6| 00000001  00111100   316 -> Found adding to stream - 316 bytearray(b'|\x00')
# [319](9)|7| 00000001  00111111   319 -> Not Found adding to stream- 316 bytearray(b'|\x00|')
# [320](9)|0| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'Q\x00')
# [321](9)|1| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'Q\x00')
# [322](9)|2| 00000001  00010111   279 -> Found adding to stream - 279 bytearray(b'\x08\x00')
# [323](9)|3| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x00')
# [324](9)|4| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [325](9)|5| 00000000  00001100   12 -> Found adding to stream - 12 b'\x0c'
# [326](9)|6| 00000001  01000101   325 -> Found adding to stream - 325 bytearray(b'\x11\x00')
# [327](9)|7| 00000000  00101100   44 -> Found adding to stream - 44 b','
# [328](9)|0| 00000000  00001100   12 -> Found adding to stream - 12 b'\x0c'
# [329](9)|1| 00000000  00001100   12 -> Found adding to stream - 12 b'\x0c'
# [330](9)|2| 00000000  00101100   44 -> Found adding to stream - 44 b','
# [331](9)|3| 00000000  00101100   44 -> Found adding to stream - 44 b','
# [332](9)|4| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [333](9)|5| 00000001  00100011   291 -> Found adding to stream - 291 bytearray(b'1\x00')
# [334](9)|6| 00000001  00100100   292 -> Found adding to stream - 292 bytearray(b'D\x00')
# [335](9)|7| 00000001  00111100   316 -> Found adding to stream - 316 bytearray(b'|\x00')
# [336](9)|0| 00000000  10000100   132 -> Found adding to stream - 132 b'\x84'
# [337](9)|1| 00000001  00000111   263 -> Found adding to stream - 263 bytearray(b'\xb0\x00')
# [338](9)|2| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b'\x84\x00')
# [339](9)|3| 00000001  00010010   274 -> Found adding to stream - 274 bytearray(b'|\x00')
# [340](9)|4| 00000001  01000001   321 -> Found adding to stream - 321 bytearray(b'Q\x00Q')
# [341](9)|5| 00000001  01000001   321 -> Found adding to stream - 321 bytearray(b'Q\x00Q')
# [342](9)|6| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'1\x00')
# [343](9)|7| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'1\x00')
# [344](9)|0| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x00')
# [345](9)|1| 00000000  00101101   45 -> Found adding to stream - 45 b'-'
# [346](9)|2| 00000000  00101101   45 -> Found adding to stream - 45 b'-'
# [347](9)|3| 00000000  00100111   39 -> Found adding to stream - 39 b"'"
# [348](9)|4| 00000001  01011100   348 -> Not Found adding to stream- 39 b"''"
# [349](9)|5| 00000000  00100111   39 -> Found adding to stream - 39 b"'"
# [350](9)|6| 00000001  01001001   329 -> Found adding to stream - 329 bytearray(b'\x0c\x00')
# [351](9)|7| 00000001  01001010   330 -> Found adding to stream - 330 bytearray(b'\x0c\x00')
# [352](9)|0| 00000001  01001100   332 -> Found adding to stream - 332 bytearray(b',\x00')
# [353](9)|1| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'1\x00')
# [354](9)|2| 00000000  01000100   68 -> Found adding to stream - 68 b'D'
# [355](9)|3| 00000001  00010110   278 -> Found adding to stream - 278 bytearray(b'\x08\x00')
# [356](9)|4| 00000001  00010111   279 -> Found adding to stream - 279 bytearray(b'\x08\x00')
# [357](9)|5| 00000000  00110001   49 -> Found adding to stream - 49 b'1'
# [358](9)|6| 00000000  01101001   105 -> Found adding to stream - 105 b'i'
# [359](9)|7| 00000000  10100111   167 -> Found adding to stream - 167 b'\xa7'
# [360](9)|0| 00000000  01011100   92 -> Found adding to stream - 92 b'\\'
# [361](9)|1| 00000000  10101101   173 -> Found adding to stream - 173 b'\xad'
# [362](9)|2| 00000000  11101000   232 -> Found adding to stream - 232 b'\xe8'
# [363](9)|3| 00000000  11101000   232 -> Found adding to stream - 232 b'\xe8'
# [364](9)|4| 00000000  00001001   9 -> Found adding to stream - 9 b'\t'
# [365](9)|5| 00000000  00001111   15 -> Found adding to stream - 15 b'\x0f'
# [366](9)|6| 00000000  00001011   11 -> Found adding to stream - 11 b'\x0b'
# [367](9)|7| 00000000  00010010   18 -> Found adding to stream - 18 b'\x12'
# [368](9)|0| 00000000  00011110   30 -> Found adding to stream - 30 b'\x1e'
# [369](9)|1| 00000000  01111010   122 -> Found adding to stream - 122 b'z'
# [370](9)|2| 00000000  10110011   179 -> Found adding to stream - 179 b'\xb3'
# [371](9)|3| 00000000  11100101   229 -> Found adding to stream - 229 b'\xe5'
# [372](9)|4| 00000000  01010110   86 -> Found adding to stream - 86 b'V'
# [373](9)|5| 00000000  10111111   191 -> Found adding to stream - 191 b'\xbf'
# [374](9)|6| 00000000  10101011   171 -> Found adding to stream - 171 b'\xab'
# [375](9)|7| 00000000  10101011   171 -> Found adding to stream - 171 b'\xab'
# [376](9)|0| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'1\x00')
# [377](9)|1| 00000000  00110011   51 -> Found adding to stream - 51 b'3'
# [378](9)|2| 00000000  00110011   51 -> Found adding to stream - 51 b'3'
# [379](9)|3| 00000000  00001100   12 -> Found adding to stream - 12 b'\x0c'
# [380](9)|4| 00000000  00001010   10 -> Found adding to stream - 10 b'\n'
# [381](9)|5| 00000000  00001000   8 -> Found adding to stream - 8 b'\x08'
# [382](9)|6| 00000000  00001010   10 -> Found adding to stream - 10 b'\n'
# [383](9)|7| 00000000  00001010   10 -> Found adding to stream - 10 b'\n'
# [384](9)|0| 00000001  01001001   329 -> Found adding to stream - 329 bytearray(b'\x0c\x00')
# [385](9)|1| 00000000  00101101   45 -> Found adding to stream - 45 b'-'
# [386](9)|2| 00000000  11010010   210 -> Found adding to stream - 210 b'\xd2'
# [387](9)|3| 00000000  11010010   210 -> Found adding to stream - 210 b'\xd2'
# [388](9)|4| 00000000  01101010   106 -> Found adding to stream - 106 b'j'
# [389](9)|5| 00000000  01010000   80 -> Found adding to stream - 80 b'P'
# [390](9)|6| 00000000  00110011   51 -> Found adding to stream - 51 b'3'
# [391](9)|7| 00000000  01101010   106 -> Found adding to stream - 106 b'j'
# [392](9)|0| 00000001  10001000   392 -> Not Found adding to stream- 106 b'jj'
# [393](9)|1| 00000000  10100111   167 -> Found adding to stream - 167 b'\xa7'
# [394](9)|2| 00000000  01110100   116 -> Found adding to stream - 116 b't'
# [395](9)|3| 00000000  10101101   173 -> Found adding to stream - 173 b'\xad'
# [396](9)|4| 00000000  10110101   181 -> Found adding to stream - 181 b'\xb5'
# [397](9)|5| 00000000  00011110   30 -> Found adding to stream - 30 b'\x1e'
# [398](9)|6| 00000000  00001111   15 -> Found adding to stream - 15 b'\x0f'
# [399](9)|7| 00000000  00001111   15 -> Found adding to stream - 15 b'\x0f'
# [400](9)|0| 00000000  00001001   9 -> Found adding to stream - 9 b'\t'
# [401](9)|1| 00000000  00001110   14 -> Found adding to stream - 14 b'\x0e'
# [402](9)|2| 00000000  00001110   14 -> Found adding to stream - 14 b'\x0e'
# [403](9)|3| 00000001  00001100   268 -> Found adding to stream - 268 bytearray(b'\x17\x00\x17\x17\x17\x17\x17')
# [404](9)|4| 00000001  00110101   309 -> Found adding to stream - 309 bytearray(b'\xb0\x00\xb0')
# [405](9)|5| 00000001  00000010   258 -> Found adding to stream - 258 bytearray(b'\x17\x00')
# [406](9)|6| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b'\x84\x00')
# [407](9)|7| 00000001  00111001   313 -> Found adding to stream - 313 bytearray(b'\x84\x00\x84\x84')
# [408](9)|0| 00000001  00001111   271 -> Found adding to stream - 271 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17')
# [409](9)|1| 00000001  10011001   409 -> Not Found adding to stream- 271 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17\x17')
# [410](9)|2| 00000001  10011010   410 -> Not Found adding to stream- 409 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17')
# [411](9)|3| 00000001  10010110   406 -> Found adding to stream - 406 bytearray(b'\x17\x00\x17')
# [412](9)|4| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b'\x84\x00')
# [413](9)|5| 00000000  01010001   81 -> Found adding to stream - 81 b'Q'
# [414](9)|6| 00000001  00011110   286 -> Found adding to stream - 286 bytearray(b'\x18\x00')
# [415](9)|7| 00000001  00011101   285 -> Found adding to stream - 285 bytearray(b'\x18\x00\x18')
# [416](9)|0| 00000001  10100000   416 -> Not Found adding to stream- 285 bytearray(b'\x18\x00\x18\x18')
# [417](9)|1| 00000001  00011111   287 -> Found adding to stream - 287 bytearray(b'\x11\x00\x11')
# [418](9)|2| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [419](9)|3| 00000001  00011110   286 -> Found adding to stream - 286 bytearray(b'\x18\x00')
# [420](9)|4| 00000001  00011111   287 -> Found adding to stream - 287 bytearray(b'\x11\x00\x11')
# [421](9)|5| 00000001  00100100   292 -> Found adding to stream - 292 bytearray(b'D\x00')
# [422](9)|6| 00000001  00100101   293 -> Found adding to stream - 293 bytearray(b'D\x00')
# [423](9)|7| 00000001  00000111   263 -> Found adding to stream - 263 bytearray(b'\xb0\x00')
# [424](9)|0| 00000001  00000110   262 -> Found adding to stream - 262 bytearray(b'\xb0\x00')
# [425](9)|1| 00000001  00000110   262 -> Found adding to stream - 262 bytearray(b'\xb0\x00')
# [426](9)|2| 00000000  10101011   171 -> Found adding to stream - 171 b'\xab'
# [427](9)|3| 00000000  10100111   167 -> Found adding to stream - 167 b'\xa7'
# [428](9)|4| 00000000  01010110   86 -> Found adding to stream - 86 b'V'
# [429](9)|5| 00000000  10110011   179 -> Found adding to stream - 179 b'\xb3'
# [430](9)|6| 00000000  01111010   122 -> Found adding to stream - 122 b'z'
# [431](9)|7| 00000000  00111111   63 -> Found adding to stream - 63 b'?'
# [432](9)|0| 00000000  01111010   122 -> Found adding to stream - 122 b'z'
# [433](9)|1| 00000001  10110001   433 -> Not Found adding to stream- 122 b'zz'
# [434](9)|2| 00000000  10101000   168 -> Found adding to stream - 168 b'\xa8'
# [435](9)|3| 00000000  01011100   92 -> Found adding to stream - 92 b'\\'
# [436](9)|4| 00000000  01000111   71 -> Found adding to stream - 71 b'G'
# [437](9)|5| 00000000  11110110   246 -> Found adding to stream - 246 b'\xf6'
# [438](9)|6| 00000001  00000111   263 -> Found adding to stream - 263 bytearray(b'\xb0\x00')
# [439](9)|7| 00000001  00000011   259 -> Found adding to stream - 259 bytearray(b'\x17\x00\x17')
# [440](9)|0| 00000001  00100111   295 -> Found adding to stream - 295 bytearray(b'\x84\x00\x17')
# [441](9)|1| 00000001  00111000   312 -> Found adding to stream - 312 bytearray(b'\x84\x00\x84')
# [442](9)|2| 00000001  00100110   294 -> Found adding to stream - 294 bytearray(b'|\x00')
# [443](9)|3| 00000001  00111000   312 -> Found adding to stream - 312 bytearray(b'\x84\x00\x84')
# [444](9)|4| 00000001  00010000   272 -> Found adding to stream - 272 bytearray(b'\x17\x00')
# [445](9)|5| 00000000  01111100   124 -> Found adding to stream - 124 b'|'
# [446](9)|6| 00000001  01010101   341 -> Found adding to stream - 341 bytearray(b'Q\x00QQ')
# [447](9)|7| 00000001  10111111   447 -> Not Found adding to stream- 341 bytearray(b'Q\x00QQQ')
# [448](9)|0| 00000001  00010101   277 -> Found adding to stream - 277 bytearray(b'Q\x00')
# [449](9)|1| 00000001  01100100   356 -> Found adding to stream - 356 bytearray(b'\x08\x00\x08')
# [450](9)|2| 00000001  00010110   278 -> Found adding to stream - 278 bytearray(b'\x08\x00')
# [451](9)|3| 00000001  00011001   281 -> Found adding to stream - 281 bytearray(b'\x11\x00')
# [452](9)|4| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [453](9)|5| 00000001  01011111   351 -> Found adding to stream - 351 bytearray(b'\x0c\x00\x0c')
# [454](9)|6| 00000001  11000110   454 -> Not Found adding to stream- 351 bytearray(b'\x0c\x00\x0c\x0c')
# [455](9)|7| 00000001  01100000   352 -> Found adding to stream - 352 bytearray(b'\x0c\x00,')
# [456](9)|0| 00000000  00001100   12 -> Found adding to stream - 12 b'\x0c'
# [457](9)|1| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [458](9)|2| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'Q\x00')
# [459](9)|3| 00000001  00100101   293 -> Found adding to stream - 293 bytearray(b'D\x00')
# [460](9)|4| 00000001  10111011   443 -> Found adding to stream - 443 bytearray(b'|\x00\x84')
# [461](9)|5| 00000001  00110111   311 -> Found adding to stream - 311 bytearray(b'\x84\x00')
# [462](9)|6| 00000001  00111100   316 -> Found adding to stream - 316 bytearray(b'|\x00')
# [463](9)|7| 00000001  00010011   275 -> Found adding to stream - 275 bytearray(b'D\x00')
# [464](9)|0| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'Q\x00')
# [465](9)|1| 00000000  11010111   215 -> Found adding to stream - 215 b'\xd7'
# [466](9)|2| 00000000  00001000   8 -> Found adding to stream - 8 b'\x08'
# [467](9)|3| 00000001  01010111   343 -> Found adding to stream - 343 bytearray(b'1\x001')
# [468](9)|4| 00000001  01111001   377 -> Found adding to stream - 377 bytearray(b'1\x001')
# [469](9)|5| 00000001  01011010   346 -> Found adding to stream - 346 bytearray(b'-\x00')
# [470](9)|6| 00000001  01001000   328 -> Found adding to stream - 328 bytearray(b',\x00')
# [471](9)|7| 00000001  11000111   455 -> Found adding to stream - 455 bytearray(b'\x0c\x00\x0c\x0c\x0c')
# [472](9)|0| 00000001  01001011   331 -> Found adding to stream - 331 bytearray(b',\x00')
# [473](9)|1| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [474](9)|2| 00000001  10111111   447 -> Found adding to stream - 447 bytearray(b'Q\x00QQQ')
# [475](9)|3| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'1\x00')
# [476](9)|4| 00000000  11010010   210 -> Found adding to stream - 210 b'\xd2'
# [477](9)|5| 00000000  11011010   218 -> Found adding to stream - 218 b'\xda'
# [478](9)|6| 00000000  01011100   92 -> Found adding to stream - 92 b'\\'
# [479](9)|7| 00000000  10101000   168 -> Found adding to stream - 168 b'\xa8'
# [480](9)|0| 00000000  11101000   232 -> Found adding to stream - 232 b'\xe8'
# [481](9)|1| 00000000  00100001   33 -> Found adding to stream - 33 b'!'
# [482](9)|2| 00000001  01101110   366 -> Found adding to stream - 366 bytearray(b'\x0f\x00')
# [483](9)|3| 00000001  01101111   367 -> Found adding to stream - 367 bytearray(b'\x0b\x00')
# [484](9)|4| 00000000  00100001   33 -> Found adding to stream - 33 b'!'
# [485](9)|5| 00000000  01000010   66 -> Found adding to stream - 66 b'B'
# [486](9)|6| 00000001  00110001   305 -> Found adding to stream - 305 bytearray(b'\xb5\x00')
# [487](9)|7| 00000000  01011100   92 -> Found adding to stream - 92 b'\\'
# [488](9)|0| 00000000  10111000   184 -> Found adding to stream - 184 b'\xb8'
# [489](9)|1| 00000000  10100010   162 -> Found adding to stream - 162 b'\xa2'
# [490](9)|2| 00000001  01111000   376 -> Found adding to stream - 376 bytearray(b'\xab\x00')
# [491](9)|3| 00000000  00110001   49 -> Found adding to stream - 49 b'1'
# [492](9)|4| 00000001  01111010   378 -> Found adding to stream - 378 bytearray(b'3\x00')
# [493](9)|5| 00000001  11000100   452 -> Found adding to stream - 452 bytearray(b'\x11\x00\x18')
# [494](9)|6| 00000001  10100000   416 -> Found adding to stream - 416 bytearray(b'\x18\x00\x18\x18')
# [495](9)|7| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [496](9)|0| 00000000  00001010   10 -> Found adding to stream - 10 b'\n'
# [497](9)|1| 00000001  10000101   389 -> Found adding to stream - 389 bytearray(b'j\x00')
# [498](9)|2| 00000000  00110011   51 -> Found adding to stream - 51 b'3'
# [499](9)|3| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x00')
# [500](9)|4| 00000000  00110011   51 -> Found adding to stream - 51 b'3'
# [501](9)|5| 00000001  01100111   359 -> Found adding to stream - 359 bytearray(b'i\x00')
# [502](9)|6| 00000000  01100100   100 -> Found adding to stream - 100 b'd'
# [503](9)|7| 00000000  10101111   175 -> Found adding to stream - 175 b'\xaf'
# [504](9)|0| 00000000  01111010   122 -> Found adding to stream - 122 b'z'
# [505](9)|1| 00000000  00011110   30 -> Found adding to stream - 30 b'\x1e'
# [506](9)|2| 00000000  00100001   33 -> Found adding to stream - 33 b'!'
# [507](9)|3| 00000001  11111011   507 -> Not Found adding to stream- 33 b'!!'
# [508](9)|4| 00000000  00001111   15 -> Found adding to stream - 15 b'\x0f'
# [509](9)|5| 00000001  10010011   403 -> Found adding to stream - 403 bytearray(b'\x0e\x00')
# [510](9)|6| 00000001  00001011   267 -> Found adding to stream - 267 bytearray(b'\x17\x00\x17\x17\x17\x17')
# [511](9)|7| 00000001  10101001   425 -> Found adding to stream - 425 bytearray(b'\xb0\x00\xb0')
# [512](10)|0| 00000001  00010000   272 -> Found adding to stream - 272 bytearray(b'\x17\x00')
# [513](10)|2| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b'\x84\x00')
# [514](10)|4| 00000001  10111101   445 -> Found adding to stream - 445 bytearray(b'\x17\x00\x84')
# [515](10)|6| 00000000  01111100   124 -> Found adding to stream - 124 b'|'
# [516](10)|0| 00000001  00001110   270 -> Found adding to stream - 270 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17')
# [517](10)|2| 00000001  10110111   439 -> Found adding to stream - 439 bytearray(b'\xb0\x00\x17')
# [518](10)|4| 00000001  10011011   411 -> Found adding to stream - 411 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17')
# [519](10)|6| 00000001  00001111   271 -> Found adding to stream - 271 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17')
# [520](10)|0| 00000001  10011101   413 -> Found adding to stream - 413 bytearray(b'\x84\x00|')
# [521](10)|2| 00000001  01011111   351 -> Found adding to stream - 351 bytearray(b'\x0c\x00\x0c')
# [522](10)|4| 00000001  10100010   418 -> Found adding to stream - 418 bytearray(b'\x11\x00\x11\x11')
# [523](10)|6| 00000001  00011111   287 -> Found adding to stream - 287 bytearray(b'\x11\x00\x11')
# [524](10)|0| 00000001  11000111   455 -> Found adding to stream - 455 bytearray(b'\x0c\x00\x0c\x0c\x0c')
# [525](10)|2| 00000001  10100100   420 -> Found adding to stream - 420 bytearray(b'\x18\x00\x11')
# [526](10)|4| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [527](10)|6| 00000001  10100110   422 -> Found adding to stream - 422 bytearray(b'D\x00D')
# [528](10)|0| 00000001  10101001   425 -> Found adding to stream - 425 bytearray(b'\xb0\x00\xb0')
# [529](10)|2| 00000010  00010001   529 -> Not Found adding to stream- 425 bytearray(b'\xb0\x00\xb0\xb0')
# [530](10)|4| 00000000  01101001   105 -> Found adding to stream - 105 b'i'
# [531](10)|6| 00000000  10000001   129 -> Found adding to stream - 129 b'\x81'
# [532](10)|0| 00000000  01010100   84 -> Found adding to stream - 84 b'T'
# [533](10)|2| 00000000  10110101   181 -> Found adding to stream - 181 b'\xb5'
# [534](10)|4| 00000001  10101111   431 -> Found adding to stream - 431 bytearray(b'z\x00')
# [535](10)|6| 00000000  01000010   66 -> Found adding to stream - 66 b'B'
# [536](10)|0| 00000001  10110001   433 -> Found adding to stream - 433 bytearray(b'z\x00')
# [537](10)|2| 00000000  10110101   181 -> Found adding to stream - 181 b'\xb5'
# [538](10)|4| 00000000  10100001   161 -> Found adding to stream - 161 b'\xa1'
# [539](10)|6| 00000000  01010100   84 -> Found adding to stream - 84 b'T'
# [540](10)|0| 00000000  10100010   162 -> Found adding to stream - 162 b'\xa2'
# [541](10)|2| 00000010  00000000   512 -> Found adding to stream - 512 bytearray(b'\xb0\x00\xb0\xb0')
# [542](10)|4| 00000001  10111000   440 -> Found adding to stream - 440 bytearray(b'\x17\x00\x17\x17')
# [543](10)|6| 00000001  11001110   462 -> Found adding to stream - 462 bytearray(b'\x84\x00\x84')
# [544](10)|0| 00000001  00111111   319 -> Found adding to stream - 319 bytearray(b'|\x00|')
# [545](10)|2| 00000001  01010000   336 -> Found adding to stream - 336 bytearray(b'|\x00|')
# [546](10)|4| 00000001  10011101   413 -> Found adding to stream - 413 bytearray(b'\x84\x00|')
# [547](10)|6| 00000001  00111011   315 -> Found adding to stream - 315 bytearray(b'Q\x00Q')
# [548](10)|0| 00000001  00111110   318 -> Found adding to stream - 318 bytearray(b'Q\x00')
# [549](10)|2| 00000001  01000001   321 -> Found adding to stream - 321 bytearray(b'Q\x00Q')
# [550](10)|4| 00000001  11000010   450 -> Found adding to stream - 450 bytearray(b'\x08\x00\x08\x08')
# [551](10)|6| 00000001  00010110   278 -> Found adding to stream - 278 bytearray(b'\x08\x00')
# [552](10)|0| 00000010  00001010   522 -> Found adding to stream - 522 bytearray(b'\x0c\x00\x0c\x0c')
# [553](10)|2| 00000001  11000111   455 -> Found adding to stream - 455 bytearray(b'\x0c\x00\x0c\x0c\x0c')
# [554](10)|4| 00000001  01011111   351 -> Found adding to stream - 351 bytearray(b'\x0c\x00\x0c')
# [555](10)|6| 00000001  01011101   349 -> Found adding to stream - 349 bytearray(b"\'\x00\'")
# [556](10)|0| 00000001  11001010   458 -> Found adding to stream - 458 bytearray(b'\x18\x00')
# [557](10)|2| 00000001  10100110   422 -> Found adding to stream - 422 bytearray(b'D\x00D')
# [558](10)|4| 00000001  00100101   293 -> Found adding to stream - 293 bytearray(b'D\x00')
# [559](10)|6| 00000010  00100000   544 -> Found adding to stream - 544 bytearray(b'\x84\x00\x84|')
# [560](10)|0| 00000001  11001111   463 -> Found adding to stream - 463 bytearray(b'|\x00|')
# [561](10)|2| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'Q\x00')
# [562](10)|4| 00000001  01111101   381 -> Found adding to stream - 381 bytearray(b'\n\x00')
# [563](10)|6| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [564](10)|0| 00000001  11010100   468 -> Found adding to stream - 468 bytearray(b'1\x0011')
# [565](10)|2| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [566](10)|4| 00000001  11010110   470 -> Found adding to stream - 470 bytearray(b'-\x00-')
# [567](10)|6| 00000010  00101010   554 -> Found adding to stream - 554 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c')
# [568](10)|0| 00000001  01001011   331 -> Found adding to stream - 331 bytearray(b',\x00')
# [569](10)|2| 00000001  01001100   332 -> Found adding to stream - 332 bytearray(b',\x00')
# [570](10)|4| 00000001  10100010   418 -> Found adding to stream - 418 bytearray(b'\x11\x00\x11\x11')
# [571](10)|6| 00000000  00110001   49 -> Found adding to stream - 49 b'1'
# [572](10)|0| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [573](10)|2| 00000000  00110011   51 -> Found adding to stream - 51 b'3'
# [574](10)|4| 00000000  11010010   210 -> Found adding to stream - 210 b'\xd2'
# [575](10)|6| 00000000  10000001   129 -> Found adding to stream - 129 b'\x81'
# [576](10)|0| 00000001  10101101   429 -> Found adding to stream - 429 bytearray(b'V\x00')
# [577](10)|2| 00000001  01101100   364 -> Found adding to stream - 364 bytearray(b'\xe8\x00')
# [578](10)|4| 00000000  00001110   14 -> Found adding to stream - 14 b'\x0e'
# [579](10)|6| 00000001  11100011   483 -> Found adding to stream - 483 bytearray(b'\x0f\x00\x0b')
# [580](10)|0| 00000000  00001111   15 -> Found adding to stream - 15 b'\x0f'
# [581](10)|2| 00000010  00011000   536 -> Found adding to stream - 536 bytearray(b'B\x00')
# [582](10)|4| 00000000  10101111   175 -> Found adding to stream - 175 b'\xaf'
# [583](10)|6| 00000000  01011100   92 -> Found adding to stream - 92 b'\\'
# [584](10)|0| 00000000  10100101   165 -> Found adding to stream - 165 b'\xa5'
# [585](10)|2| 00000000  10100010   162 -> Found adding to stream - 162 b'\xa2'
# [586](10)|4| 00000000  01010000   80 -> Found adding to stream - 80 b'P'
# [587](10)|6| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'1\x00')
# [588](10)|0| 00000010  00111101   573 -> Found adding to stream - 573 bytearray(b'\x11\x00')
# [589](10)|2| 00000001  11101110   494 -> Found adding to stream - 494 bytearray(b'\x11\x00\x18\x18')
# [590](10)|4| 00000001  10100000   416 -> Found adding to stream - 416 bytearray(b'\x18\x00\x18\x18')
# [591](10)|6| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'1\x00')
# [592](10)|0| 00000000  01101010   106 -> Found adding to stream - 106 b'j'
# [593](10)|2| 00000001  11110011   499 -> Found adding to stream - 499 bytearray(b'3\x00')
# [594](10)|4| 00000000  00011000   24 -> Found adding to stream - 24 b'\x18'
# [595](10)|6| 00000000  01010000   80 -> Found adding to stream - 80 b'P'
# [596](10)|0| 00000000  01101001   105 -> Found adding to stream - 105 b'i'
# [597](10)|2| 00000001  11011110   478 -> Found adding to stream - 478 bytearray(b'\xda\x00')
# [598](10)|4| 00000001  11111000   504 -> Found adding to stream - 504 bytearray(b'\xaf\x00')
# [599](10)|6| 00000001  11111011   507 -> Found adding to stream - 507 bytearray(b'!\x00')
# [600](10)|0| 00000001  11100101   485 -> Found adding to stream - 485 bytearray(b'!\x00')
# [601](10)|2| 00000001  11111101   509 -> Found adding to stream - 509 bytearray(b'\x0f\x00')
# [602](10)|4| 00000001  00001101   269 -> Found adding to stream - 269 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17')
# [603](10)|6| 00000000  10110000   176 -> Found adding to stream - 176 b'\xb0'
# [604](10)|0| 00000001  11001110   462 -> Found adding to stream - 462 bytearray(b'\x84\x00\x84')
# [605](10)|2| 00000001  00111000   312 -> Found adding to stream - 312 bytearray(b'\x84\x00\x84')
# [606](10)|4| 00000001  10100110   422 -> Found adding to stream - 422 bytearray(b'D\x00D')
# [607](10)|6| 00000000  01111100   124 -> Found adding to stream - 124 b'|'
# [608](10)|0| 00000001  10010101   405 -> Found adding to stream - 405 bytearray(b'\xb0\x00\xb0\x17')
# [609](10)|2| 00000001  00110111   311 -> Found adding to stream - 311 bytearray(b'\x84\x00')
# [610](10)|4| 00000001  00000011   259 -> Found adding to stream - 259 bytearray(b'\x17\x00\x17')
# [611](10)|6| 00000010  00000110   518 -> Found adding to stream - 518 bytearray(b'\xb0\x00\x17\x17')
# [612](10)|0| 00000010  00000111   519 -> Found adding to stream - 519 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17')
# [613](10)|2| 00000001  00001010   266 -> Found adding to stream - 266 bytearray(b'\x17\x00\x17\x17\x17')
# [614](10)|4| 00000001  01010011   339 -> Found adding to stream - 339 bytearray(b'\x84\x00|')
# [615](10)|6| 00000001  10011110   414 -> Found adding to stream - 414 bytearray(b'Q\x00')
# [616](10)|0| 00000010  00101010   554 -> Found adding to stream - 554 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c')
# [617](10)|2| 00000010  01101001   617 -> Not Found adding to stream- 554 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c\x0c')
# [618](10)|4| 00000001  01001001   329 -> Found adding to stream - 329 bytearray(b'\x0c\x00')
# [619](10)|6| 00000010  00001110   526 -> Found adding to stream - 526 bytearray(b'\x18\x00\x11\x11')
# [620](10)|0| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [621](10)|2| 00000010  01011111   607 -> Found adding to stream - 607 bytearray(b'D\x00DD')
# [622](10)|4| 00000010  01011100   604 -> Found adding to stream - 604 bytearray(b'\xb0\x00')
# [623](10)|6| 00000001  01010001   337 -> Found adding to stream - 337 bytearray(b'\x84\x00')
# [624](10)|0| 00000000  10110000   176 -> Found adding to stream - 176 b'\xb0'
# [625](10)|2| 00000000  11110110   246 -> Found adding to stream - 246 b'\xf6'
# [626](10)|4| 00000000  10110001   177 -> Found adding to stream - 177 b'\xb1'
# [627](10)|6| 00000000  10011001   153 -> Found adding to stream - 153 b'\x99'
# [628](10)|0| 00000001  10001100   396 -> Found adding to stream - 396 bytearray(b'\xad\x00')
# [629](10)|2| 00000001  11111001   505 -> Found adding to stream - 505 bytearray(b'z\x00')
# [630](10)|4| 00000000  01000010   66 -> Found adding to stream - 66 b'B'
# [631](10)|6| 00000010  00011000   536 -> Found adding to stream - 536 bytearray(b'B\x00')
# [632](10)|0| 00000000  01111010   122 -> Found adding to stream - 122 b'z'
# [633](10)|2| 00000000  10101101   173 -> Found adding to stream - 173 b'\xad'
# [634](10)|4| 00000000  01010110   86 -> Found adding to stream - 86 b'V'
# [635](10)|6| 00000000  10111000   184 -> Found adding to stream - 184 b'\xb8'
# [636](10)|0| 00000001  10110110   438 -> Found adding to stream - 438 bytearray(b'\xf6\x00')
# [637](10)|2| 00000001  00001000   264 -> Found adding to stream - 264 bytearray(b'\x17\x00\x17\x17\x17')
# [638](10)|4| 00000010  00000001   513 -> Found adding to stream - 513 bytearray(b'\x17\x00\x84')
# [639](10)|6| 00000010  00100001   545 -> Found adding to stream - 545 bytearray(b'|\x00||')
# [640](10)|0| 00000010  00100001   545 -> Found adding to stream - 545 bytearray(b'|\x00||')
# [641](10)|2| 00000001  01010101   341 -> Found adding to stream - 341 bytearray(b'Q\x00QQ')
# [642](10)|4| 00000001  01100100   356 -> Found adding to stream - 356 bytearray(b'\x08\x00\x08')
# [643](10)|6| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x00')
# [644](10)|0| 00000001  01111110   382 -> Found adding to stream - 382 bytearray(b'\x08\x00')
# [645](10)|2| 00000001  01111111   383 -> Found adding to stream - 383 bytearray(b'\n\x00')
# [646](10)|4| 00000001  01111101   381 -> Found adding to stream - 381 bytearray(b'\n\x00')
# [647](10)|6| 00000000  00001000   8 -> Found adding to stream - 8 b'\x08'
# [648](10)|0| 00000000  00001100   12 -> Found adding to stream - 12 b'\x0c'
# [649](10)|2| 00000001  01011110   350 -> Found adding to stream - 350 bytearray(b"\'\x00")
# [650](10)|4| 00000001  11001000   456 -> Found adding to stream - 456 bytearray(b'\x0c\x00,,')
# [651](10)|6| 00000001  11011000   472 -> Found adding to stream - 472 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c')
# [652](10)|0| 00000001  01001011   331 -> Found adding to stream - 331 bytearray(b',\x00')
# [653](10)|2| 00000000  00001100   12 -> Found adding to stream - 12 b'\x0c'
# [654](10)|4| 00000001  01001110   334 -> Found adding to stream - 334 bytearray(b'1\x00D')
# [655](10)|6| 00000010  00101110   558 -> Found adding to stream - 558 bytearray(b'D\x00DD')
# [656](10)|0| 00000010  10010000   656 -> Not Found adding to stream- 558 bytearray(b'D\x00DDD')
# [657](10)|2| 00000001  00010011   275 -> Found adding to stream - 275 bytearray(b'D\x00')
# [658](10)|4| 00000001  01111110   382 -> Found adding to stream - 382 bytearray(b'\x08\x00')
# [659](10)|6| 00000000  00001000   8 -> Found adding to stream - 8 b'\x08'
# [660](10)|0| 00000001  00011101   285 -> Found adding to stream - 285 bytearray(b'\x18\x00\x18')
# [661](10)|2| 00000001  01011000   344 -> Found adding to stream - 344 bytearray(b'1\x001')
# [662](10)|4| 00000010  00110110   566 -> Found adding to stream - 566 bytearray(b'\x18\x00')
# [663](10)|6| 00000010  01101010   618 -> Found adding to stream - 618 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c\x0c\x0c')
# [664](10)|0| 00000001  00011111   287 -> Found adding to stream - 287 bytearray(b'\x11\x00\x11')
# [665](10)|2| 00000010  00111001   569 -> Found adding to stream - 569 bytearray(b',\x00,')
# [666](10)|4| 00000001  01001101   333 -> Found adding to stream - 333 bytearray(b'\x11\x00')
# [667](10)|6| 00000000  00110001   49 -> Found adding to stream - 49 b'1'
# [668](10)|0| 00000000  01010000   80 -> Found adding to stream - 80 b'P'
# [669](10)|2| 00000000  10110001   177 -> Found adding to stream - 177 b'\xb1'
# [670](10)|4| 00000000  01100100   100 -> Found adding to stream - 100 b'd'
# [671](10)|6| 00000000  11100101   229 -> Found adding to stream - 229 b'\xe5'
# [672](10)|0| 00000000  10110101   181 -> Found adding to stream - 181 b'\xb5'
# [673](10)|2| 00000010  01000010   578 -> Found adding to stream - 578 bytearray(b'\xe8\x00\t')
# [674](10)|4| 00000010  01000100   580 -> Found adding to stream - 580 bytearray(b'\x0f\x00\x0b\x0b')
# [675](10)|6| 00000000  01000010   66 -> Found adding to stream - 66 b'B'
# [676](10)|0| 00000000  11101000   232 -> Found adding to stream - 232 b'\xe8'
# [677](10)|2| 00000000  10110011   179 -> Found adding to stream - 179 b'\xb3'
# [678](10)|4| 00000000  10100001   161 -> Found adding to stream - 161 b'\xa1'
# [679](10)|6| 00000000  00101111   47 -> Found adding to stream - 47 b'/'
# [680](10)|0| 00000000  01101001   105 -> Found adding to stream - 105 b'i'
# [681](10)|2| 00000000  10101011   171 -> Found adding to stream - 171 b'\xab'
# [682](10)|4| 00000000  00110011   51 -> Found adding to stream - 51 b'3'
# [683](10)|6| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [684](10)|0| 00000010  10101011   683 -> Found adding to stream - 683 bytearray(b'3\x00')
# [685](10)|2| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x00')
# [686](10)|4| 00000010  10001001   649 -> Found adding to stream - 649 bytearray(b'\x0c\x00')
# [687](10)|6| 00000001  01011100   348 -> Found adding to stream - 348 bytearray(b"\'\x00")
# [688](10)|0| 00000001  01000110   326 -> Found adding to stream - 326 bytearray(b'\x0c\x00')
# [689](10)|2| 00000001  01111010   378 -> Found adding to stream - 378 bytearray(b'3\x00')
# [690](10)|4| 00000000  00101101   45 -> Found adding to stream - 45 b'-'
# [691](10)|6| 00000001  00011001   281 -> Found adding to stream - 281 bytearray(b'\x11\x00')
# [692](10)|0| 00000010  01010100   596 -> Found adding to stream - 596 bytearray(b'P\x00')
# [693](10)|2| 00000010  01010110   598 -> Found adding to stream - 598 bytearray(b'\xda\x00\\')
# [694](10)|4| 00000001  11111001   505 -> Found adding to stream - 505 bytearray(b'z\x00')
# [695](10)|6| 00000000  00010010   18 -> Found adding to stream - 18 b'\x12'
# [696](10)|0| 00000010  01011001   601 -> Found adding to stream - 601 bytearray(b'!\x00B')
# [697](10)|2| 00000001  11111110   510 -> Found adding to stream - 510 bytearray(b'\x0e\x00\x17')
# [698](10)|4| 00000010  01100110   614 -> Found adding to stream - 614 bytearray(b'\x17\x00\x17\x17\x17\x17')
# [699](10)|6| 00000010  01011110   606 -> Found adding to stream - 606 bytearray(b'\x84\x00\x84\x84')
# [700](10)|0| 00000001  00111111   319 -> Found adding to stream - 319 bytearray(b'|\x00|')
# [701](10)|2| 00000010  00101110   558 -> Found adding to stream - 558 bytearray(b'D\x00DD')
# [702](10)|4| 00000001  00111111   319 -> Found adding to stream - 319 bytearray(b'|\x00|')
# [703](10)|6| 00000001  10010111   407 -> Found adding to stream - 407 bytearray(b'\x84\x00|')
# [704](10)|0| 00000001  00001010   266 -> Found adding to stream - 266 bytearray(b'\x17\x00\x17\x17\x17')
# [705](10)|2| 00000010  01100100   612 -> Found adding to stream - 612 bytearray(b'\xb0\x00\x17\x17\x17')
# [706](10)|4| 00000010  01100101   613 -> Found adding to stream - 613 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17')
# [707](10)|6| 00000001  00000010   258 -> Found adding to stream - 258 bytearray(b'\x17\x00')
# [708](10)|0| 00000010  00100110   550 -> Found adding to stream - 550 bytearray(b'Q\x00QQ')
# [709](10)|2| 00000001  01000101   325 -> Found adding to stream - 325 bytearray(b'\x11\x00')
# [710](10)|4| 00000010  01101010   618 -> Found adding to stream - 618 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c\x0c\x0c')
# [711](10)|6| 00000010  00001101   525 -> Found adding to stream - 525 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c')
# [712](10)|0| 00000001  10100010   418 -> Found adding to stream - 418 bytearray(b'\x11\x00\x11\x11')
# [713](10)|2| 00000010  01011111   607 -> Found adding to stream - 607 bytearray(b'D\x00DD')
# [714](10)|4| 00000001  00111100   316 -> Found adding to stream - 316 bytearray(b'|\x00')
# [715](10)|6| 00000001  10110110   438 -> Found adding to stream - 438 bytearray(b'\xf6\x00')
# [716](10)|0| 00000010  01110001   625 -> Found adding to stream - 625 bytearray(b'\xb0\x00')
# [717](10)|2| 00000010  01010110   598 -> Found adding to stream - 598 bytearray(b'\xda\x00\\')
# [718](10)|4| 00000001  00101111   303 -> Found adding to stream - 303 bytearray(b'\xe8\x00')
# [719](10)|6| 00000000  00011110   30 -> Found adding to stream - 30 b'\x1e'
# [720](10)|0| 00000000  00011110   30 -> Found adding to stream - 30 b'\x1e'
# [721](10)|2| 00000010  01110111   631 -> Found adding to stream - 631 bytearray(b'B\x00')
# [722](10)|4| 00000000  01000010   66 -> Found adding to stream - 66 b'B'
# [723](10)|6| 00000010  10100110   678 -> Found adding to stream - 678 bytearray(b'\xb3\x00')
# [724](10)|0| 00000000  10010011   147 -> Found adding to stream - 147 b'\x93'
# [725](10)|2| 00000010  00011101   541 -> Found adding to stream - 541 bytearray(b'\xa2\x00')
# [726](10)|4| 00000001  10110111   439 -> Found adding to stream - 439 bytearray(b'\xb0\x00\x17')
# [727](10)|6| 00000001  00111010   314 -> Found adding to stream - 314 bytearray(b'\x84\x00\x84\x84\x84')
# [728](10)|0| 00000000  10000100   132 -> Found adding to stream - 132 b'\x84'
# [729](10)|2| 00000001  11000000   448 -> Found adding to stream - 448 bytearray(b'Q\x00QQQQ')
# [730](10)|4| 00000001  11000001   449 -> Found adding to stream - 449 bytearray(b'Q\x00\x08')
# [731](10)|6| 00000010  00101000   552 -> Found adding to stream - 552 bytearray(b'\x08\x00\x08')
# [732](10)|0| 00000010  10101110   686 -> Found adding to stream - 686 bytearray(b'\x18\x00\x18')
# [733](10)|2| 00000000  00101100   44 -> Found adding to stream - 44 b','
# [734](10)|4| 00000010  10001010   650 -> Found adding to stream - 650 bytearray(b"\'\x00\x0c")
# [735](10)|6| 00000010  01101011   619 -> Found adding to stream - 619 bytearray(b'\x0c\x00\x0c')
# [736](10)|0| 00000001  01000101   325 -> Found adding to stream - 325 bytearray(b'\x11\x00')
# [737](10)|2| 00000010  10001010   650 -> Found adding to stream - 650 bytearray(b"\'\x00\x0c")
# [738](10)|4| 00000010  10001101   653 -> Found adding to stream - 653 bytearray(b',\x00,')
# [739](10)|6| 00000001  11000111   455 -> Found adding to stream - 455 bytearray(b'\x0c\x00\x0c\x0c\x0c')
# [740](10)|0| 00000001  01011101   349 -> Found adding to stream - 349 bytearray(b"\'\x00\'")
# [741](10)|2| 00000001  01100001   353 -> Found adding to stream - 353 bytearray(b',\x00\x11')
# [742](10)|4| 00000001  01001110   334 -> Found adding to stream - 334 bytearray(b'1\x00D')
# [743](10)|6| 00000001  11010100   468 -> Found adding to stream - 468 bytearray(b'1\x0011')
# [744](10)|0| 00000010  00101110   558 -> Found adding to stream - 558 bytearray(b'D\x00DD')
# [745](10)|2| 00000010  00111100   572 -> Found adding to stream - 572 bytearray(b'1\x00')
# [746](10)|4| 00000010  00110011   563 -> Found adding to stream - 563 bytearray(b'\n\x00\x08')
# [747](10)|6| 00000001  10100001   417 -> Found adding to stream - 417 bytearray(b'\x18\x00\x18\x18\x18')
# [748](10)|0| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [749](10)|2| 00000010  01101001   617 -> Found adding to stream - 617 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c\x0c')
# [750](10)|4| 00000010  00111010   570 -> Found adding to stream - 570 bytearray(b',\x00\x11')
# [751](10)|6| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [752](10)|0| 00000010  10011010   666 -> Found adding to stream - 666 bytearray(b',\x00,,')
# [753](10)|2| 00000010  00110110   566 -> Found adding to stream - 566 bytearray(b'\x18\x00')
# [754](10)|4| 00000000  01101010   106 -> Found adding to stream - 106 b'j'
# [755](10)|6| 00000000  01111101   125 -> Found adding to stream - 125 b'}'
# [756](10)|0| 00000001  10001011   395 -> Found adding to stream - 395 bytearray(b't\x00')
# [757](10)|2| 00000000  10110101   181 -> Found adding to stream - 181 b'\xb5'
# [758](10)|4| 00000000  01000010   66 -> Found adding to stream - 66 b'B'
# [759](10)|6| 00000001  10010001   401 -> Found adding to stream - 401 bytearray(b'\t\x00')
# [760](10)|0| 00000000  00010010   18 -> Found adding to stream - 18 b'\x12'
# [761](10)|2| 00000000  00001011   11 -> Found adding to stream - 11 b'\x0b'
# [762](10)|4| 00000000  00001111   15 -> Found adding to stream - 15 b'\x0f'
# [763](10)|6| 00000001  11100101   485 -> Found adding to stream - 485 bytearray(b'!\x00')
# [764](10)|0| 00000001  11100110   486 -> Found adding to stream - 486 bytearray(b'B\x00')
# [765](10)|2| 00000010  00011011   539 -> Found adding to stream - 539 bytearray(b'\xa1\x00')
# [766](10)|4| 00000000  11101001   233 -> Found adding to stream - 233 b'\xe9'
# [767](10)|6| 00000001  10000110   390 -> Found adding to stream - 390 bytearray(b'P\x00')
# [768](10)|0| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [769](10)|2| 00000010  10110011   691 -> Found adding to stream - 691 bytearray(b'-\x00')
# [770](10)|4| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x00')
# [771](10)|6| 00000010  11011110   734 -> Found adding to stream - 734 bytearray(b',\x00')
# [772](10)|0| 00000001  01011101   349 -> Found adding to stream - 349 bytearray(b"\'\x00\'")
# [773](10)|2| 00000001  11010011   467 -> Found adding to stream - 467 bytearray(b'\x08\x00')
# [774](10)|4| 00000010  10101011   683 -> Found adding to stream - 683 bytearray(b'3\x00')
# [775](10)|6| 00000010  10001110   654 -> Found adding to stream - 654 bytearray(b'\x0c\x00')
# [776](10)|0| 00000000  01101010   106 -> Found adding to stream - 106 b'j'
# [777](10)|2| 00000000  11010010   210 -> Found adding to stream - 210 b'\xd2'
# [778](10)|4| 00000000  10010011   147 -> Found adding to stream - 147 b'\x93'
# [779](10)|6| 00000001  10101101   429 -> Found adding to stream - 429 bytearray(b'V\x00')
# [780](10)|0| 00000000  01111010   122 -> Found adding to stream - 122 b'z'
# [781](10)|2| 00000000  01110111   119 -> Found adding to stream - 119 b'w'
# [782](10)|4| 00000001  11111010   506 -> Found adding to stream - 506 bytearray(b'\x1e\x00')
# [783](10)|6| 00000001  10001110   398 -> Found adding to stream - 398 bytearray(b'\x1e\x00')
# [784](10)|0| 00000010  10111010   698 -> Found adding to stream - 698 bytearray(b'\x0e\x00\x17\x17')
# [785](10)|2| 00000001  00000100   260 -> Found adding to stream - 260 bytearray(b'\x17\x00\x17\x17')
# [786](10)|4| 00000001  01010000   336 -> Found adding to stream - 336 bytearray(b'|\x00|')
# [787](10)|6| 00000001  00010010   274 -> Found adding to stream - 274 bytearray(b'|\x00')
# [788](10)|0| 00000010  10010001   657 -> Found adding to stream - 657 bytearray(b'D\x00DDDD')
# [789](10)|2| 00000001  00100101   293 -> Found adding to stream - 293 bytearray(b'D\x00')
# [790](10)|4| 00000001  01001111   335 -> Found adding to stream - 335 bytearray(b'D\x00D')
# [791](10)|6| 00000001  00100110   294 -> Found adding to stream - 294 bytearray(b'|\x00')
# [792](10)|0| 00000010  11000011   707 -> Found adding to stream - 707 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17\x17')
# [793](10)|2| 00000010  00001000   520 -> Found adding to stream - 520 bytearray(b'\x17\x00\x17\x17\x17\x17\x17\x17\x17\x17\x17')
# [794](10)|4| 00000000  01010001   81 -> Found adding to stream - 81 b'Q'
# [795](10)|6| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [796](10)|0| 00000001  01100100   356 -> Found adding to stream - 356 bytearray(b'\x08\x00\x08')
# [797](10)|2| 00000010  11000110   710 -> Found adding to stream - 710 bytearray(b'\x11\x00\x0c')
# [798](10)|4| 00000010  11000111   711 -> Found adding to stream - 711 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c\x0c\x0c\x0c')
# [799](10)|6| 00000010  11100000   736 -> Found adding to stream - 736 bytearray(b'\x0c\x00\x0c\x18')
# [800](10)|0| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x11\x00')
# [801](10)|2| 00000010  10001111   655 -> Found adding to stream - 655 bytearray(b'1\x00DD')
# [802](10)|4| 00000001  11001100   460 -> Found adding to stream - 460 bytearray(b'D\x00|')
# [803](10)|6| 00000000  11110110   246 -> Found adding to stream - 246 b'\xf6'
# [804](10)|0| 00000001  10110110   438 -> Found adding to stream - 438 bytearray(b'\xf6\x00')
# ...
# [3307](12)|3| 00000000  01001010   74 -> Found adding to stream - 74 b'J'
# [3308](12)|7| 00001100  00011000   3096 -> Found adding to stream - 3096 bytearray(b'\x00\x00\x00\r\r')
# [3309](12)|3| 00001100  01110001   3185 -> Found adding to stream - 3185 bytearray(b'\r\x00\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r')
# [3310](12)|7| 00000001  00100001   289 -> Found adding to stream - 289 bytearray(b'\xc8\x00')
# [3311](12)|3| 00000000  10000011   131 -> Found adding to stream - 131 b'\x83'
# [3312](12)|7| 00000001  11000011   451 -> Found adding to stream - 451 bytearray(b'!\x00')
# [3313](12)|3| 00001010  00001101   2573 -> Found adding to stream - 2573 bytearray(b'\x12\x00\x12\x0e')
# [3314](12)|7| 00000010  00010100   532 -> Found adding to stream - 532 bytearray(b'\x0e\x00\x0e\x0e')
# [3315](12)|3| 00000011  00010111   791 -> Found adding to stream - 791 bytearray(b'\x12\x00\x12')
# [3316](12)|7| 00000010  10011100   668 -> Found adding to stream - 668 bytearray(b'\x06\x00\x06\x0e')
# [3317](12)|3| 00000000  00001111   15 -> Found adding to stream - 15 b'\x0f'
# [3318](12)|7| 00000000  00011110   30 -> Found adding to stream - 30 b'\x1e'
# [3319](12)|3| 00000000  11101000   232 -> Found adding to stream - 232 b'\xe8'
# [3320](12)|7| 00000000  10101000   168 -> Found adding to stream - 168 b'\xa8'
# [3321](12)|3| 00000010  01001101   589 -> Found adding to stream - 589 bytearray(b'\xe5\x00')
# [3322](12)|7| 00000000  10010111   151 -> Found adding to stream - 151 b'\x97'
# [3323](12)|3| 00000010  00111010   570 -> Found adding to stream - 570 bytearray(b'H\x00')
# [3324](12)|7| 00000001  01011001   345 -> Found adding to stream - 345 bytearray(b'`\x00')
# [3325](12)|3| 00000000  01110100   116 -> Found adding to stream - 116 b't'
# [3326](12)|7| 00000011  10001100   908 -> Found adding to stream - 908 bytearray(b'\xad\x00')
# [3327](12)|3| 00000110  10011011   1691 -> Found adding to stream - 1691 bytearray(b'w\x00')
# [3328](12)|7| 00000000  00100001   33 -> Found adding to stream - 33 b'!'
# [3329](12)|3| 00001001  10010000   2448 -> Found adding to stream - 2448 bytearray(b'\x0e\x00')
# [3330](12)|7| 00000001  11000111   455 -> Found adding to stream - 455 bytearray(b'\x12\x00')
# [3331](12)|3| 00001000  10111101   2237 -> Found adding to stream - 2237 bytearray(b'\x0e\x00\x0e\x0f\x0e')
# [3332](12)|7| 00001001  10100111   2471 -> Found adding to stream - 2471 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c,')
# [3333](12)|3| 00000010  10111010   698 -> Found adding to stream - 698 bytearray(b"\'\x00")
# [3334](12)|7| 00001100  10100111   3239 -> Found adding to stream - 3239 bytearray(b'\x08\x00')
# [3335](12)|3| 00000000  01010001   81 -> Found adding to stream - 81 b'Q'
# [3336](12)|7| 00001101  00001000   3336 -> Not Found adding to stream- 81 b'QQ'
# [3337](12)|3| 00000011  11000010   962 -> Found adding to stream - 962 bytearray(b'Q\x00')
# [3338](12)|7| 00000010  00110101   565 -> Found adding to stream - 565 bytearray(b'P\x00i')
# [3339](12)|3| 00001100  01000010   3138 -> Found adding to stream - 3138 bytearray(b'{\x00')
# [3340](12)|7| 00000110  00110111   1591 -> Found adding to stream - 1591 bytearray(b'T\x00')
# [3341](12)|3| 00000000  01101100   108 -> Found adding to stream - 108 b'l'
# [3342](12)|7| 00000110  01000110   1606 -> Found adding to stream - 1606 bytearray(b'>\x00')
# [3343](12)|3| 00000000  01100000   96 -> Found adding to stream - 96 b'`'
# [3344](12)|7| 00000000  10111000   184 -> Found adding to stream - 184 b'\xb8'
# [3345](12)|3| 00001101  00010001   3345 -> Not Found adding to stream- 184 b'\xb8\xb8'
# [3346](12)|7| 00001011  10011010   2970 -> Found adding to stream - 2970 bytearray(b'`\x00')
# [3347](12)|3| 00000011  00000110   774 -> Found adding to stream - 774 bytearray(b'y\x00')
# [3348](12)|7| 00001010  10000010   2690 -> Found adding to stream - 2690 bytearray(b'\x97\x00')
# [3349](12)|3| 00000101  11011010   1498 -> Found adding to stream - 1498 bytearray(b'e\x00')
# [3350](12)|7| 00000000  01000111   71 -> Found adding to stream - 71 b'G'
# [3351](12)|3| 00001100  10110110   3254 -> Found adding to stream - 3254 bytearray(b'/\x00')
# [3352](12)|7| 00001100  10110111   3255 -> Found adding to stream - 3255 bytearray(b'/\x00/')
# [3353](12)|3| 00001011  11111111   3071 -> Found adding to stream - 3071 bytearray(b'G\x00G')
# [3354](12)|7| 00001001  10111010   2490 -> Found adding to stream - 2490 bytearray(b'\x04\x00')
# [3355](12)|3| 00000000  01011100   92 -> Found adding to stream - 92 b'\\'
# [3356](12)|7| 00000000  01100001   97 -> Found adding to stream - 97 b'a'
# [3357](12)|3| 00000000  01110010   114 -> Found adding to stream - 114 b'r'
# [3358](12)|7| 00000000  00000100   4 -> Found adding to stream - 4 b'\x04'
# [3359](12)|3| 00000000  01001101   77 -> Found adding to stream - 77 b'M'
# [3360](12)|7| 00001001  01101001   2409 -> Found adding to stream - 2409 bytearray(b'\xcf\x00')
# [3361](12)|3| 00001011  11000000   3008 -> Found adding to stream - 3008 bytearray(b'\xcb\x00\xb6')
# [3362](12)|7| 00000011  01100000   864 -> Found adding to stream - 864 bytearray(b'f\x00')
# [3363](12)|3| 00000111  11111110   2046 -> Found adding to stream - 2046 bytearray(b'8\x00')
# [3364](12)|7| 00001001  11001001   2505 -> Found adding to stream - 2505 bytearray(b'c\x00')
# [3365](12)|3| 00000000  10110010   178 -> Found adding to stream - 178 b'\xb2'
# [3366](12)|7| 00000000  11010100   212 -> Found adding to stream - 212 b'\xd4'
# [3367](12)|3| 00000000  11110101   245 -> Found adding to stream - 245 b'\xf5'
# [3368](12)|7| 00001010  10111000   2744 -> Found adding to stream - 2744 bytearray(b'\xf9\x00[')
# [3369](12)|3| 00001000  10011010   2202 -> Found adding to stream - 2202 bytearray(b'E\x00[')
# [3370](12)|7| 00001100  01101100   3180 -> Found adding to stream - 3180 bytearray(b'E\x00E[')
# [3371](12)|3| 00000000  11111100   252 -> Found adding to stream - 252 b'\xfc'
# [3372](12)|7| 00000000  10101111   175 -> Found adding to stream - 175 b'\xaf'
# [3373](12)|3| 00001100  01110000   3184 -> Found adding to stream - 3184 bytearray(b'\x00\x00\r\r\r\r\r')
# [3374](12)|7| 00001100  10001010   3210 -> Found adding to stream - 3210 bytearray(b'\r\x00\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r')
# [3375](12)|3| 00001011  00000111   2823 -> Found adding to stream - 2823 bytearray(b'\x00\x00')
# [3376](12)|7| 00000000  01110011   115 -> Found adding to stream - 115 b's'
# [3377](12)|3| 00001100  00011101   3101 -> Found adding to stream - 3101 bytearray(b'\xdf\x00')
# [3378](12)|7| 00001001  11001010   2506 -> Found adding to stream - 2506 bytearray(b'\x9c\x00')
# [3379](12)|3| 00000000  10111110   190 -> Found adding to stream - 190 b'\xbe'
# [3380](12)|7| 00000000  11101100   236 -> Found adding to stream - 236 b'\xec'
# [3381](12)|3| 00000000  11000011   195 -> Found adding to stream - 195 b'\xc3'
# [3382](12)|7| 00000000  11101111   239 -> Found adding to stream - 239 b'\xef'
# [3383](12)|3| 00000000  11011000   216 -> Found adding to stream - 216 b'\xd8'
# [3384](12)|7| 00001000  00001111   2063 -> Found adding to stream - 2063 bytearray(b'\xd9\x00\xeb')
# [3385](12)|3| 00000101  11111011   1531 -> Found adding to stream - 1531 bytearray(b'\x9c\x00g')
# [3386](12)|7| 00000100  11000100   1220 -> Found adding to stream - 1220 bytearray(b'g\x00g')
# [3387](12)|3| 00000010  11110010   754 -> Found adding to stream - 754 bytearray(b'g\x00')
# [3388](12)|7| 00000010  11110011   755 -> Found adding to stream - 755 bytearray(b'g\x00')
# [3389](12)|3| 00000010  11101011   747 -> Found adding to stream - 747 bytearray(b'c\x00')
# [3390](12)|7| 00000010  11110100   756 -> Found adding to stream - 756 bytearray(b'\xb6\x00\xb6')
# [3391](12)|3| 00000000  11101011   235 -> Found adding to stream - 235 b'\xeb'
# [3392](12)|7| 00000000  11100111   231 -> Found adding to stream - 231 b'\xe7'
# [3393](12)|3| 00000000  11011001   217 -> Found adding to stream - 217 b'\xd9'
# [3394](12)|7| 00000000  10010101   149 -> Found adding to stream - 149 b'\x95'
# [3395](12)|3| 00000000  10111110   190 -> Found adding to stream - 190 b'\xbe'
# [3396](12)|7| 00000011  11111011   1019 -> Found adding to stream - 1019 bytearray(b'\xdb\x00')
# [3397](12)|3| 00000110  00011000   1560 -> Found adding to stream - 1560 bytearray(b'\x90\x00')
# [3398](12)|7| 00001100  11101100   3308 -> Found adding to stream - 3308 bytearray(b'J\x00')
# [3399](12)|3| 00001100  11001101   3277 -> Found adding to stream - 3277 bytearray(b'\r\x00\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r')
# [3400](12)|7| 00000000  00001101   13 -> Found adding to stream - 13 b'\r'
# [3401](12)|3| 00000000  01000110   70 -> Found adding to stream - 70 b'F'
# [3402](12)|7| 00000011  00101000   808 -> Found adding to stream - 808 bytearray(b'\xc1\x00')
# [3403](12)|3| 00000000  01110111   119 -> Found adding to stream - 119 b'w'
# [3404](12)|7| 00000001  10000001   385 -> Found adding to stream - 385 bytearray(b'!\x00')
# [3405](12)|3| 00000100  00010001   1041 -> Found adding to stream - 1041 bytearray(b'!\x00\x0f')
# [3406](12)|7| 00000010  00010010   530 -> Found adding to stream - 530 bytearray(b'\x0e\x00\x0e')
# [3407](12)|3| 00001100  11110001   3313 -> Found adding to stream - 3313 bytearray(b'!\x00\x0f')
# [3408](12)|7| 00001101  00000011   3331 -> Found adding to stream - 3331 bytearray(b'\x12\x00\x06')
# [3409](12)|3| 00000111  01101001   1897 -> Found adding to stream - 1897 bytearray(b'\x0e\x00')
# [3410](12)|7| 00001011  11101101   3053 -> Found adding to stream - 3053 bytearray(b'\x0b\x00')
# [3411](12)|3| 00000011  01001101   845 -> Found adding to stream - 845 bytearray(b'z\x00')
# [3412](12)|7| 00001001  10011011   2459 -> Found adding to stream - 2459 bytearray(b'\xa8\x00')
# [3413](12)|3| 00000000  10101101   173 -> Found adding to stream - 173 b'\xad'
# [3414](12)|7| 00000000  00111110   62 -> Found adding to stream - 62 b'>'
# [3415](12)|3| 00000000  11010011   211 -> Found adding to stream - 211 b'\xd3'
# [3416](12)|7| 00000000  11010011   211 -> Found adding to stream - 211 b'\xd3'
# [3417](12)|3| 00000000  10100101   165 -> Found adding to stream - 165 b'\xa5'
# [3418](12)|7| 00001100  11111110   3326 -> Found adding to stream - 3326 bytearray(b't\x00')
# [3419](12)|3| 00001000  10111010   2234 -> Found adding to stream - 2234 bytearray(b'z\x00')
# [3420](12)|7| 00000100  00010001   1041 -> Found adding to stream - 1041 bytearray(b'!\x00\x0f')
# [3421](12)|3| 00001100  10100000   3232 -> Found adding to stream - 3232 bytearray(b'\x0b\x00')
# [3422](12)|7| 00001011  10001100   2956 -> Found adding to stream - 2956 bytearray(b'\x0b\x00\x0e')
# [3423](12)|3| 00001100  10100011   3235 -> Found adding to stream - 3235 bytearray(b'\x0f\x00\x0e\x0e\x0c\x0c')
# [3424](12)|7| 00000111  01101100   1900 -> Found adding to stream - 1900 bytearray(b'\x0c\x00\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c')
# [3425](12)|3| 00001001  00111001   2361 -> Found adding to stream - 2361 bytearray(b",\x00\'")
# [3426](12)|7| 00000000  00010001   17 -> Found adding to stream - 17 b'\x11'
# [3427](12)|3| 00001101  00001001   3337 -> Found adding to stream - 3337 bytearray(b'Q\x00Q')
# [3428](12)|7| 00001101  00001001   3337 -> Found adding to stream - 3337 bytearray(b'Q\x00Q')
# [3429](12)|3| 00000001  10100100   420 -> Found adding to stream - 420 bytearray(b'1\x00')
# [3430](12)|7| 00000100  00001100   1036 -> Found adding to stream - 1036 bytearray(b'\xd2\x00')
# [3431](12)|3| 00000110  00110110   1590 -> Found adding to stream - 1590 bytearray(b'd\x00')
# [3432](12)|7| 00000011  00000110   774 -> Found adding to stream - 774 bytearray(b'y\x00')
# [3433](12)|3| 00000000  11100101   229 -> Found adding to stream - 229 b'\xe5'
# [3434](12)|7| 00000000  01100010   98 -> Found adding to stream - 98 b'b'
# [3435](12)|3| 00000000  00101111   47 -> Found adding to stream - 47 b'/'
# [3436](12)|7| 00000000  01010110   86 -> Found adding to stream - 86 b'V'
# [3437](12)|3| 00001100  01000010   3138 -> Found adding to stream - 3138 bytearray(b'{\x00')
# [3438](12)|7| 00001001  01001000   2376 -> Found adding to stream - 2376 bytearray(b'\\\x00V')
# [3439](12)|3| 00000110  01001011   1611 -> Found adding to stream - 1611 bytearray(b'T\x00')
# [3440](12)|7| 00001010  10000010   2690 -> Found adding to stream - 2690 bytearray(b'\x97\x00')
# [3441](12)|3| 00000010  10000111   647 -> Found adding to stream - 647 bytearray(b'V\x00')
# [3442](12)|7| 00001101  00010111   3351 -> Found adding to stream - 3351 bytearray(b'G\x00')
# [3443](12)|3| 00000000  01000111   71 -> Found adding to stream - 71 b'G'
# [3444](12)|7| 00000000  10100111   167 -> Found adding to stream - 167 b'\xa7'
# [3445](12)|3| 00001100  01011010   3162 -> Found adding to stream - 3162 bytearray(b'/\x00')
# [3446](12)|7| 00001100  10110111   3255 -> Found adding to stream - 3255 bytearray(b'/\x00/')
# [3447](12)|3| 00001011  01000011   2883 -> Found adding to stream - 2883 bytearray(b'\x04\x00')
# [3448](12)|7| 00000000  11100101   229 -> Found adding to stream - 229 b'\xe5'
# [3449](12)|3| 00001011  10100101   2981 -> Found adding to stream - 2981 bytearray(b'a\x00e')
# [3450](12)|7| 00000000  01000111   71 -> Found adding to stream - 71 b'G'
# [3451](12)|3| 00000000  11101010   234 -> Found adding to stream - 234 b'\xea'
# [3452](12)|7| 00000000  10011011   155 -> Found adding to stream - 155 b'\x9b'
# [3453](12)|3|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 TestImage('jake(240x240).bin','jake(240x240)-ColorTable.txt',(240,240),8)
#
# Cell In[65], line 150, in TestImage(ImagePath, ColorTablePath, frameSize, min_code)
#     146 ColorTable = newColorTable
#     148 src = open(ImagePath, "rb")
# --> 150 decompressed = lzw_Decompress(src,min_code)
#     151 src.close()
#     152 # Create a blank white RGB image
#
# Cell In[65], line 48, in lzw_Decompress(src, LZW_Min_Code)
#      46 print('['+str(newTableIndex)+']',end="")
#      47 print('('+str(CodeLen)+')',end="")
# ---> 48 print('|'+str(BitIndex)+'|',end="")
#      49 for i in range(CodeLen):
#      50     if ByteCount == 0:
#
# File /usr/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3029, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3027 def write(data, *args, **kwargs):
#    3028     """Write data to both the original destination and the capture dictionary."""
# -> 3029     result = original_write(data, *args, **kwargs)
#    3030     if any(
#    3031         [
#    3032             self.display_pub.is_publishing,
#    (...)   3035         ]
#    3036     ):
#    3037         return result
#
# File /usr/lib/python3.13/site-packages/ipykernel/iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File /usr/lib/python3.13/site-packages/ipykernel/iostream.py:590, in OutStream._schedule_flush(self)
#     587 def _schedule_in_thread():
#     588     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 590 self.pub_thread.schedule(_schedule_in_thread)
#
# File /usr/lib/python3.13/site-packages/ipykernel/iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File /usr/lib/python3.13/site-packages/zmq/sugar/socket.py:701, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     694         data = zmq.Frame(
#     695             data,
#     696             track=track,
#     697             copy=copy or None,
#     698             copy_threshold=self.copy_threshold,
#     699         )
#     700     data.group = group
# --> 701 return super().send(data, flags=flags, copy=copy, track=track)
#
# File _zmq.py:1092, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1140, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1339, in zmq.backend.cython._zmq._send_copy()
#
# File _zmq.py:160, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:

# %%
TestImage('jake_64_colors(240x240).bin','jake_64_colors(240x240)-ColorTable.txt',(240,240),6)
# Out:
# CodeTable len:  697
# <PIL.Image.Image image mode=RGB size=240x240>

# %%
TestImage('steam_boat_monocrome(128x64).bin','steam_boat_monocrome(128x64)-ColorTable.txt',(128,64),2)
# Out:
# CodeTable len:  686
# <PIL.Image.Image image mode=RGB size=128x64>
