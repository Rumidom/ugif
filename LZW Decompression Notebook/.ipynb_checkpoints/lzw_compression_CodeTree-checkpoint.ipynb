# %%
from PIL import Image
from IPython.display import display

#resources:
#http://warp.povusers.org/EfficientLZW/part4.html
#https://giflib.sourceforge.net/whatsinagif/index.html
#https://github.com/qalle2/pygif
#https://bitbanksoftware.blogspot.com/2020/07/a-low-memory-gif-decoder.html

# %%
class treeNode():
    def __init__(self):
        self.index = None
        self.byte = None
        self.left = None
        self.right = None
        
    def getList(self,code,numColors):
        currentNode = self
        while True:
            if currentNode == None:
                return outList
            if currentNode.byte < numColors:
                outList = [currentNode.byte]
            if currentNode == code:
                outList.append(currentNode.byte) 
                return outList
            if code < currentNode.index:
                outList.append(currentNode.byte) 
                currentNode = currentNode.left 
            else:
                outList.append(currentNode.byte) 
                currentNode = currentNode.right

    def append(self,code,byte):
        currentNode = self        
        while True:
            print(code,currentNode.index)
            if currentNode.index == code:
                return False
            elif currentNode.index == None:
                #print("setting",code)
                currentNode.index = code
                if currentNode.byte == None:
                    currentNode.byte = byte
                    return True
            elif code < currentNode.index:
                #print("left")
                if currentNode.left == None:
                    currentNode.left = treeNode()
                currentNode = currentNode.left 
            else:
                #print("right")
                if currentNode.right == None:
                    currentNode.right = treeNode()
                currentNode = currentNode.right
                    
def ByteArrayReverse(Barr):
    l = list(Barr)
    l = l[::-1]
    return bytearray(l)
    
def get_CodeValue(Code,treeNode,ColorTableLen):
    if Code < ColorTableLen:
        return Code.to_bytes(1)
    else:
        newCode = Code
        outList = treeNode.getList(Code,ColorTableLen)
        outList = outList[::-1]
        return bytearray(outList)
        
#def get_CodeValue(Code,codeTable,ColorTableLen):
    #if Code < ColorTableLen:
        #return Code.to_bytes(1)
    #else:
        #tup = codeTable[Code-(ColorTableLen+2)]
        #output = get_CodeValue(tup[0],codeTable,ColorTableLen) + tup[1]
        #print(output)
        #return output
def lzw_Decompress(src,LZW_Min_Code):
    ColorTableLen = 2**LZW_Min_Code
    print('ColorTableLen:',ColorTableLen)
    print('LZW_Min_Code:',LZW_Min_Code)
    ClearCode = ColorTableLen
    ImgEndCode = ColorTableLen + 1
    CodeLen = LZW_Min_Code+1
    lastCode = 0
    K = 0
    Code = None
    Codekey = None
    indexStream = bytearray()
    datablock = bytearray(256)
    datablockIndex = 0
    codeTree = treeNode()
    byte = 0
    BitIndex = 0
    newTableIndex = ImgEndCode + 1
    ByteCount = 0
    BlockN = 0
    FirstCodeFlag = False
    ZeroBlockLenFlag = False
    while True:       
        Code = bytearray(CodeLen//8+1)
        print('bc:',ByteCount,' ',end='')
        print('['+str(newTableIndex)+']',end="")
        print('('+str(CodeLen)+')',end="")
        print('|'+str(BitIndex)+'|',end="")
        for i in range(CodeLen):   
            if ByteCount == 0:
                ByteCount = src.read(1)[0]
                datablock = src.read(ByteCount)
                datablockIndex = 0
                #print("BlockN: ",BlockN,"BlockLen: ",ByteCount)
                if ByteCount == 0:
                    ZeroBlockLenFlag = True
                    break
                BlockN += 1
                            
            if BitIndex == 0:
                byte = datablock[datablockIndex]
                datablockIndex += 1
                ByteCount -= 1

            bit = (byte >> BitIndex) & 1
            #print(bit,end="")
            if bit:
                Code[i//8] = Code[i//8] | 1<<i%8
            BitIndex += 1
            if BitIndex == 8:
                BitIndex = 0
        if ZeroBlockLenFlag:
            break
        print(' ',end="")
        binary_string = ''.join(f'{b:08b}' for b in bytearray([Code[-1]]))
        print(binary_string,' ',end="")
        binary_string = ''.join(f'{b:08b}' for b in bytearray([Code[0]]))
        print(binary_string,' ',end="")
        
        CodeKey = int.from_bytes(Code,'little')
        print(' ',end="")
        print(CodeKey,end="")
        print(' -> ',end="")
        #print('')
        if CodeKey == ClearCode:
            print('Clear Code - Initializing codeTable')
            codeTree = treeNode()
            newTableIndex = ImgEndCode+1
            FirstCodeFlag = False
            CodeLen = LZW_Min_Code+1         
        elif CodeKey == ImgEndCode:
            print('Image End Code - Decoding Complete')
            break
        else:
            if not FirstCodeFlag:
                print('First Code - Appending to indexStream')
                indexStream += bytearray(get_CodeValue(CodeKey,codeTree,ColorTableLen))
                FirstCodeFlag = True
            else:
                if (CodeKey < newTableIndex):
                    codearr = get_CodeValue(CodeKey,codeTree,ColorTableLen)
                    indexStream += bytearray(codearr)
                    K = codearr[0]
                    print('Found adding to stream -',CodeKey,bytearray(codearr))
                else:
                    lastcodearr = get_CodeValue(lastCode,codeTree,ColorTableLen)
                    K = lastcodearr[0]
                    indexStream += bytearray(lastcodearr) + bytearray([K])
                    print('Not Found adding to stream-',lastCode,bytearray(lastcodearr) + bytearray([K]))

                #codeTable[newTableIndex] = bytearray(get_CodeValue(lastCode,codeTable,ColorTableLen)) + bytearray([K])
                #codeTable.append((lastCode, bytearray([K])))
                #codeTable.append( (lastCode,K) )
                codeTree.append(lastCode,K)
                if newTableIndex >= 2**CodeLen-1:
                    print('TableIndex maxed out! ',newTableIndex)
                    print('Increased to: ',2**(CodeLen+1)-1)
                    if CodeLen < 12:
                        CodeLen += 1
                    
                newTableIndex += 1
        lastCode = CodeKey
    return indexStream

def blit(arr,callback,startPos,frameSize,ColorTable):
    scr_y = startPos[1]
    count = 0
    for i,byte in enumerate(arr):
        scr_x = i%frameSize[0] + startPos[0]
        if scr_x == startPos[0] and i != 0:
             scr_y+= 1
        callback(scr_x,scr_y,ColorTable[byte])


def TestImage(ImagePath,ColorTablePath,frameSize,min_code):
    ColorTable = []
    newColorTable = []
    
    with open(ColorTablePath, 'r') as file:
        ColorTable = [tuple(line.strip().replace('(','').replace(')','').split(", ")) for line in file.readlines()]
        
    for color in ColorTable:
        tup = (int(color[0]),int(color[1]),int(color[2]))
        newColorTable.append(tup)
    ColorTable = newColorTable
    
    src = open(ImagePath, "rb")
    
    decompressed = lzw_Decompress(src,min_code)
    src.close()
    # Create a blank white RGB image
    img = Image.new('RGB', frameSize, color='white')
    def setPixel(x,y,color):
        px = img.load()
        px[x,y] = color

    blit(decompressed,setPixel,(0,0),frameSize,ColorTable)
    display(img)

# %%
TestImage('jake(240x240).bin','jake(240x240)-ColorTable.txt',(240,240),8)
# Out:
# ColorTableLen: 256
# LZW_Min_Code: 8
# bc: 0  [258](9)|0| 00000001  00000000   256 -> Clear Code - Initializing codeTable
# bc: 253  [258](9)|1| 00000000  00010111   23 -> First Code - Appending to indexStream
# bc: 252  [258](9)|2| 00000001  00000010   258 -> Not Found adding to stream- 23 bytearray(b'\x17\x17')
# 23 None
# bc: 251  [259](9)|3| 00000001  00000011   259 -> Not Found adding to stream- 258 bytearray(b'\x17\x17\x17')
# 258 23
# 258 None
# bc: 250  [260](9)|4| 00000000  00010111   23 -> Found adding to stream - 23 bytearray(b'\x17')
# 259 23
# 259 258
# 259 None
# bc: 249  [261](9)|5| 00000000  10110000   176 -> Found adding to stream - 176 bytearray(b'\xb0')
# 23 23
# bc: 248  [262](9)|6| 00000000  10110000   176 -> Found adding to stream - 176 bytearray(b'\xb0')
# 176 23
# 176 258
# 176 None
# bc: 247  [263](9)|7| 00000001  00000100   260 -> Found adding to stream - 260 bytearray(b'\x17\x17')
# 176 23
# 176 258
# 176 176
# bc: 246  [264](9)|0| 00000000  10000100   132 -> Found adding to stream - 132 bytearray(b'\x84')
# 260 23
# 260 258
# 260 259
# 260 None
# bc: 244  [265](9)|1| 00000001  00000100   260 -> Found adding to stream - 260 bytearray(b'\x84\x84')
# 132 23
# 132 258
# 132 176
# 132 None
# bc: 243  [266](9)|2| 00000001  00001010   266 -> Not Found adding to stream- 260 bytearray(b'\x84\x84\x84')
# 260 23
# 260 258
# 260 259
# 260 260
# bc: 242  [267](9)|3| 00000001  00001011   267 -> Not Found adding to stream- 266 bytearray(b'\x84\x84\x84')
# 266 23
# 266 258
# 266 259
# 266 260
# 266 None
# bc: 241  [268](9)|4| 00000001  00001100   268 -> Not Found adding to stream- 267 bytearray(b'\x84\x84\x84')
# 267 23
# 267 258
# 267 259
# 267 260
# 267 266
# 267 None
# bc: 240  [269](9)|5| 00000001  00001101   269 -> Not Found adding to stream- 268 bytearray(b'\x84\x84\x84')
# 268 23
# 268 258
# 268 259
# 268 260
# 268 266
# 268 267
# 268 None
# bc: 239  [270](9)|6| 00000001  00001110   270 -> Not Found adding to stream- 269 bytearray(b'\x84\x84\x84')
# 269 23
# 269 258
# 269 259
# 269 260
# 269 266
# 269 267
# 269 268
# 269 None
# bc: 238  [271](9)|7| 00000000  00010111   23 -> Found adding to stream - 23 bytearray(b'\x17')
# 270 23
# 270 258
# 270 259
# 270 260
# 270 266
# 270 267
# 270 268
# 270 269
# 270 None
# bc: 237  [272](9)|0| 00000000  10000100   132 -> Found adding to stream - 132 bytearray(b'\x84')
# 23 23
# bc: 235  [273](9)|1| 00000000  01111100   124 -> Found adding to stream - 124 bytearray(b'|')
# 132 23
# 132 258
# 132 176
# 132 132
# bc: 234  [274](9)|2| 00000000  01000100   68 -> Found adding to stream - 68 bytearray(b'D')
# 124 23
# 124 258
# 124 176
# 124 132
# 124 None
# bc: 233  [275](9)|3| 00000000  01010001   81 -> Found adding to stream - 81 bytearray(b'Q')
# 68 23
# 68 258
# 68 176
# 68 132
# 68 124
# 68 None
# bc: 232  [276](9)|4| 00000000  01010001   81 -> Found adding to stream - 81 bytearray(b'Q')
# 81 23
# 81 258
# 81 176
# 81 132
# 81 124
# 81 68
# 81 None
# bc: 231  [277](9)|5| 00000000  00001000   8 -> Found adding to stream - 8 bytearray(b'\x08')
# 81 23
# 81 258
# 81 176
# 81 132
# 81 124
# 81 68
# 81 81
# bc: 230  [278](9)|6| 00000000  00001000   8 -> Found adding to stream - 8 bytearray(b'\x08')
# 8 23
# 8 None
# bc: 229  [279](9)|7| 00000000  00010001   17 -> Found adding to stream - 17 bytearray(b'\x11')
# 8 23
# 8 8
# bc: 228  [280](9)|0| 00000000  00010001   17 -> Found adding to stream - 17 bytearray(b'\x11')
# 17 23
# 17 8
# 17 None
# bc: 226  [281](9)|1| 00000000  00011000   24 -> Found adding to stream - 24 bytearray(b'\x18')
# 17 23
# 17 8
# 17 17
# bc: 225  [282](9)|2| 00000001  00010110   278 -> Found adding to stream - 278 bytearray(b'\x17\x17')
# 24 23
# 24 258
# 24 176
# 24 132
# 24 124
# 24 68
# 24 None
# bc: 224  [283](9)|3| 00000000  00011000   24 -> Found adding to stream - 24 bytearray(b'\x18')
# 278 23
# 278 258
# 278 259
# 278 260
# 278 266
# 278 267
# 278 268
# 278 269
# 278 270
# 278 None
# bc: 223  [284](9)|4| 00000001  00011100   284 -> Not Found adding to stream- 24 bytearray(b'\x18\x18')
# 24 23
# 24 258
# 24 176
# 24 132
# 24 124
# 24 68
# 24 24
# bc: 222  [285](9)|5| 00000000  00011000   24 -> Found adding to stream - 24 bytearray(b'\x18')
# 284 23
# 284 258
# 284 259
# 284 260
# 284 266
# 284 267
# 284 268
# 284 269
# 284 270
# 284 278
# 284 None
# bc: 221  [286](9)|6| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x18\x18')
# 24 23
# 24 258
# 24 176
# 24 132
# 24 124
# 24 68
# 24 24
# bc: 220  [287](9)|7| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x18\x18')
# 280 23
# 280 258
# 280 259
# 280 260
# 280 266
# 280 267
# 280 268
# 280 269
# 280 270
# 280 278
# 280 284
# 280 None
# bc: 219  [288](9)|0| 00000000  00101100   44 -> Found adding to stream - 44 bytearray(b',')
# 280 23
# 280 258
# 280 259
# 280 260
# 280 266
# 280 267
# 280 268
# 280 269
# 280 270
# 280 278
# 280 284
# 280 280
# bc: 217  [289](9)|1| 00000000  00110001   49 -> Found adding to stream - 49 bytearray(b'1')
# 44 23
# 44 258
# 44 176
# 44 132
# 44 124
# 44 68
# 44 24
# 44 None
# bc: 216  [290](9)|2| 00000000  00110001   49 -> Found adding to stream - 49 bytearray(b'1')
# 49 23
# 49 258
# 49 176
# 49 132
# 49 124
# 49 68
# 49 24
# 49 44
# 49 None
# bc: 215  [291](9)|3| 00000000  01000100   68 -> Found adding to stream - 68 bytearray(b'D')
# 49 23
# 49 258
# 49 176
# 49 132
# 49 124
# 49 68
# 49 24
# 49 44
# 49 49
# bc: 214  [292](9)|4| 00000000  01000100   68 -> Found adding to stream - 68 bytearray(b'D')
# 68 23
# 68 258
# 68 176
# 68 132
# 68 124
# 68 68
# bc: 213  [293](9)|5| 00000000  01111100   124 -> Found adding to stream - 124 bytearray(b'|')
# 68 23
# 68 258
# 68 176
# 68 132
# 68 124
# 68 68
# bc: 212  [294](9)|6| 00000001  00001001   265 -> Found adding to stream - 265 bytearray(b'\x84\x84')
# 124 23
# 124 258
# 124 176
# 124 132
# 124 124
# bc: 211  [295](9)|7| 00000001  00000100   260 -> Found adding to stream - 260 bytearray(b'\x84\x84')
# 265 23
# 265 258
# 265 259
# 265 260
# 265 266
# 265 None
# bc: 210  [296](9)|0| 00000000  10110000   176 -> Found adding to stream - 176 bytearray(b'\xb0')
# 260 23
# 260 258
# 260 259
# 260 260
# bc: 208  [297](9)|1| 00000000  11101001   233 -> Found adding to stream - 233 bytearray(b'\xe9')
# 176 23
# 176 258
# 176 176
# bc: 207  [298](9)|2| 00000000  01111011   123 -> Found adding to stream - 123 bytearray(b'{')
# 233 23
# 233 258
# 233 176
# 233 None
# bc: 206  [299](9)|3| 00000000  00000100   4 -> Found adding to stream - 4 bytearray(b'\x04')
# 123 23
# 123 258
# 123 176
# 123 132
# 123 124
# 123 68
# 123 81
# 123 None
# bc: 205  [300](9)|4| 00000000  10110101   181 -> Found adding to stream - 181 bytearray(b'\xb5')
# 4 23
# 4 8
# 4 None
# bc: 204  [301](9)|5| 00000000  00111111   63 -> Found adding to stream - 63 bytearray(b'?')
# 181 23
# 181 258
# 181 176
# 181 233
# 181 None
# bc: 203  [302](9)|6| 00000000  11101000   232 -> Found adding to stream - 232 bytearray(b'\xe8')
# 63 23
# 63 258
# 63 176
# 63 132
# 63 124
# 63 68
# 63 24
# 63 44
# 63 49
# 63 None
# bc: 202  [303](9)|7| 00000000  01111010   122 -> Found adding to stream - 122 bytearray(b'z')
# 232 23
# 232 258
# 232 176
# 232 233
# 232 181
# 232 None
# bc: 201  [304](9)|0| 00000000  10110101   181 -> Found adding to stream - 181 bytearray(b'\xb5')
# 122 23
# 122 258
# 122 176
# 122 132
# 122 124
# 122 68
# 122 81
# 122 123
# 122 None
# bc: 199  [305](9)|1| 00000000  10101101   173 -> Found adding to stream - 173 bytearray(b'\xad')
# 181 23
# 181 258
# 181 176
# 181 233
# 181 181
# bc: 198  [306](9)|2| 00000000  01011100   92 -> Found adding to stream - 92 bytearray(b'\\')
# 173 23
# 173 258
# 173 176
# 173 132
# 173 None
# bc: 197  [307](9)|3| 00000000  00110110   54 -> Found adding to stream - 54 bytearray(b'6')
# 92 23
# 92 258
# 92 176
# 92 132
# 92 124
# 92 68
# 92 81
# 92 123
# 92 122
# 92 None
# bc: 196  [308](9)|4| 00000001  00000110   262 -> Found adding to stream - 262 bytearray(b'\x84\x84')
# 54 23
# 54 258
# 54 176
# 54 132
# 54 124
# 54 68
# 54 24
# 54 44
# 54 49
# 54 63
# 54 None
# bc: 195  [309](9)|5| 00000001  00001101   269 -> Found adding to stream - 269 bytearray(b'\x17\x17')
# 262 23
# 262 258
# 262 259
# 262 260
# 262 266
# 262 265
# 262 None
# bc: 194  [310](9)|6| 00000000  10000100   132 -> Found adding to stream - 132 bytearray(b'\x84')
# 269 23
# 269 258
# 269 259
# 269 260
# 269 266
# 269 267
# 269 268
# 269 269
# bc: 193  [311](9)|7| 00000001  00110111   311 -> Not Found adding to stream- 132 bytearray(b'\x84\x84')
# 132 23
# 132 258
# 132 176
# 132 132
# bc: 192  [312](9)|0| 00000001  00111000   312 -> Not Found adding to stream- 311 bytearray(b'\x18\x18\x18')
# 311 23
# 311 258
# 311 259
# 311 260
# 311 266
# 311 267
# 311 268
# 311 269
# 311 270
# 311 278
# 311 284
# 311 None
# bc: 190  [313](9)|1| 00000001  00111001   313 -> Not Found adding to stream- 312 bytearray(b'\x18\x18\x18')
# 312 23
# 312 258
# 312 259
# 312 260
# 312 266
# 312 267
# 312 268
# 312 269
# 312 270
# 312 278
# 312 284
# 312 311
# 312 None
# bc: 189  [314](9)|2| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'\x18\x18')
# 313 23
# 313 258
# 313 259
# 313 260
# 313 266
# 313 267
# 313 268
# 313 269
# 313 270
# 313 278
# 313 284
# 313 311
# 313 312
# 313 None
# bc: 188  [315](9)|3| 00000000  01111100   124 -> Found adding to stream - 124 bytearray(b'|')
# 276 23
# 276 258
# 276 259
# 276 260
# 276 266
# 276 267
# 276 268
# 276 269
# 276 270
# 276 278
# 276 None
# bc: 187  [316](9)|4| 00000001  00111100   316 -> Not Found adding to stream- 124 bytearray(b'||')
# 124 23
# 124 258
# 124 176
# 124 132
# 124 124
# bc: 186  [317](9)|5| 00000000  01010001   81 -> Found adding to stream - 81 bytearray(b'Q')
# 316 23
# 316 258
# 316 259
# 316 260
# 316 266
# 316 267
# 316 268
# 316 269
# 316 270
# 316 278
# 316 284
# 316 311
# 316 312
# 316 313
# 316 None
# bc: 185  [318](9)|6| 00000001  00111100   316 -> Found adding to stream - 316 bytearray(b'QQ')
# 81 23
# 81 258
# 81 176
# 81 132
# 81 124
# 81 68
# 81 81
# bc: 184  [319](9)|7| 00000001  00111111   319 -> Not Found adding to stream- 316 bytearray(b'QQQ')
# 316 23
# 316 258
# 316 259
# 316 260
# 316 266
# 316 267
# 316 268
# 316 269
# 316 270
# 316 278
# 316 284
# 316 311
# 316 312
# 316 313
# 316 316
# bc: 183  [320](9)|0| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'||')
# 319 23
# 319 258
# 319 259
# 319 260
# 319 266
# 319 267
# 319 268
# 319 269
# 319 270
# 319 278
# 319 284
# 319 311
# 319 312
# 319 313
# 319 316
# 319 None
# bc: 181  [321](9)|1| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'||')
# 276 23
# 276 258
# 276 259
# 276 260
# 276 266
# 276 267
# 276 268
# 276 269
# 276 270
# 276 278
# 276 276
# bc: 180  [322](9)|2| 00000001  00010111   279 -> Found adding to stream - 279 bytearray(b'\x18\x18')
# 276 23
# 276 258
# 276 259
# 276 260
# 276 266
# 276 267
# 276 268
# 276 269
# 276 270
# 276 278
# 276 276
# bc: 179  [323](9)|3| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x18')
# 279 23
# 279 258
# 279 259
# 279 260
# 279 266
# 279 267
# 279 268
# 279 269
# 279 270
# 279 278
# 279 284
# 279 280
# 279 None
# bc: 178  [324](9)|4| 00000000  00010001   17 -> Found adding to stream - 17 bytearray(b'\x11')
# 284 23
# 284 258
# 284 259
# 284 260
# 284 266
# 284 267
# 284 268
# 284 269
# 284 270
# 284 278
# 284 284
# bc: 177  [325](9)|5| 00000000  00001100   12 -> Found adding to stream - 12 bytearray(b'\x0c')
# 17 23
# 17 8
# 17 17
# bc: 176  [326](9)|6| 00000001  01000101   325 -> Found adding to stream - 325 bytearray(b'||')
# 12 23
# 12 8
# 12 17
# 12 None
# bc: 175  [327](9)|7| 00000000  00101100   44 -> Found adding to stream - 44 bytearray(b',')
# 325 23
# 325 258
# 325 259
# 325 260
# 325 266
# 325 267
# 325 268
# 325 269
# 325 270
# 325 278
# 325 284
# 325 311
# 325 312
# 325 313
# 325 316
# 325 319
# 325 None
# bc: 174  [328](9)|0| 00000000  00001100   12 -> Found adding to stream - 12 bytearray(b'\x0c')
# 44 23
# 44 258
# 44 176
# 44 132
# 44 124
# 44 68
# 44 24
# 44 44
# bc: 172  [329](9)|1| 00000000  00001100   12 -> Found adding to stream - 12 bytearray(b'\x0c')
# 12 23
# 12 8
# 12 17
# 12 12
# bc: 171  [330](9)|2| 00000000  00101100   44 -> Found adding to stream - 44 bytearray(b',')
# 12 23
# 12 8
# 12 17
# 12 12
# bc: 170  [331](9)|3| 00000000  00101100   44 -> Found adding to stream - 44 bytearray(b',')
# 44 23
# 44 258
# 44 176
# 44 132
# 44 124
# 44 68
# 44 24
# 44 44
# bc: 169  [332](9)|4| 00000000  00010001   17 -> Found adding to stream - 17 bytearray(b'\x11')
# 44 23
# 44 258
# 44 176
# 44 132
# 44 124
# 44 68
# 44 24
# 44 44
# bc: 168  [333](9)|5| 00000001  00100011   291 -> Found adding to stream - 291 bytearray(b'\x18\x18')
# 17 23
# 17 8
# 17 17
# bc: 167  [334](9)|6| 00000001  00100100   292 -> Found adding to stream - 292 bytearray(b'\x18\x18')
# 291 23
# 291 258
# 291 259
# 291 260
# 291 266
# 291 267
# 291 268
# 291 269
# 291 270
# 291 278
# 291 284
# 291 311
# 291 None
# bc: 166  [335](9)|7| 00000001  00111100   316 -> Found adding to stream - 316 bytearray(b'||')
# 292 23
# 292 258
# 292 259
# 292 260
# 292 266
# 292 267
# 292 268
# 292 269
# 292 270
# 292 278
# 292 284
# 292 311
# 292 291
# 292 None
# bc: 165  [336](9)|0| 00000000  10000100   132 -> Found adding to stream - 132 bytearray(b'\x84')
# 316 23
# 316 258
# 316 259
# 316 260
# 316 266
# 316 267
# 316 268
# 316 269
# 316 270
# 316 278
# 316 284
# 316 311
# 316 312
# 316 313
# 316 316
# bc: 163  [337](9)|1| 00000001  00000111   263 -> Found adding to stream - 263 bytearray(b'\x17\x17')
# 132 23
# 132 258
# 132 176
# 132 132
# bc: 162  [338](9)|2| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b'||')
# 263 23
# 263 258
# 263 259
# 263 260
# 263 266
# 263 265
# 263 262
# 263 None
# bc: 161  [339](9)|3| 00000001  00010010   274 -> Found adding to stream - 274 bytearray(b'||')
# 273 23
# 273 258
# 273 259
# 273 260
# 273 266
# 273 267
# 273 268
# 273 269
# 273 270
# 273 278
# 273 276
# 273 None
# bc: 160  [340](9)|4| 00000001  01000001   321 -> Found adding to stream - 321 bytearray(b',,')
# 274 23
# 274 258
# 274 259
# 274 260
# 274 266
# 274 267
# 274 268
# 274 269
# 274 270
# 274 278
# 274 276
# 274 273
# 274 None
# bc: 159  [341](9)|5| 00000001  01000001   321 -> Found adding to stream - 321 bytearray(b',,')
# 321 23
# 321 258
# 321 259
# 321 260
# 321 266
# 321 267
# 321 268
# 321 269
# 321 270
# 321 278
# 321 284
# 321 311
# 321 312
# 321 313
# 321 316
# 321 319
# 321 325
# 321 None
# bc: 158  [342](9)|6| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'\x18\x18')
# 321 23
# 321 258
# 321 259
# 321 260
# 321 266
# 321 267
# 321 268
# 321 269
# 321 270
# 321 278
# 321 284
# 321 311
# 321 312
# 321 313
# 321 316
# 321 319
# 321 325
# 321 321
# bc: 157  [343](9)|7| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'\x18\x18')
# 290 23
# 290 258
# 290 259
# 290 260
# 290 266
# 290 267
# 290 268
# 290 269
# 290 270
# 290 278
# 290 284
# 290 311
# 290 291
# 290 None
# bc: 156  [344](9)|0| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x18')
# 290 23
# 290 258
# 290 259
# 290 260
# 290 266
# 290 267
# 290 268
# 290 269
# 290 270
# 290 278
# 290 284
# 290 311
# 290 291
# 290 290
# bc: 154  [345](9)|1| 00000000  00101101   45 -> Found adding to stream - 45 bytearray(b'-')
# 284 23
# 284 258
# 284 259
# 284 260
# 284 266
# 284 267
# 284 268
# 284 269
# 284 270
# 284 278
# 284 284
# bc: 153  [346](9)|2| 00000000  00101101   45 -> Found adding to stream - 45 bytearray(b'-')
# 45 23
# 45 258
# 45 176
# 45 132
# 45 124
# 45 68
# 45 24
# 45 44
# 45 49
# 45 None
# bc: 152  [347](9)|3| 00000000  00100111   39 -> Found adding to stream - 39 bytearray(b"\'")
# 45 23
# 45 258
# 45 176
# 45 132
# 45 124
# 45 68
# 45 24
# 45 44
# 45 49
# 45 45
# bc: 151  [348](9)|4| 00000001  01011100   348 -> Not Found adding to stream- 39 bytearray(b"\'\'")
# 39 23
# 39 258
# 39 176
# 39 132
# 39 124
# 39 68
# 39 24
# 39 44
# 39 None
# bc: 150  [349](9)|5| 00000000  00100111   39 -> Found adding to stream - 39 bytearray(b"\'")
# 348 23
# 348 258
# 348 259
# 348 260
# 348 266
# 348 267
# 348 268
# 348 269
# 348 270
# 348 278
# 348 284
# 348 311
# 348 312
# 348 313
# 348 316
# 348 319
# 348 325
# 348 None
# bc: 149  [350](9)|6| 00000001  01001001   329 -> Found adding to stream - 329 bytearray(b"\'\'")
# 39 23
# 39 258
# 39 176
# 39 132
# 39 124
# 39 68
# 39 24
# 39 44
# 39 39
# bc: 148  [351](9)|7| 00000001  01001010   330 -> Found adding to stream - 330 bytearray(b"\'\'")
# 329 23
# 329 258
# 329 259
# 329 260
# 329 266
# 329 267
# 329 268
# 329 269
# 329 270
# 329 278
# 329 284
# 329 311
# 329 312
# 329 313
# 329 316
# 329 319
# 329 325
# 329 348
# 329 None
# bc: 147  [352](9)|0| 00000001  01001100   332 -> Found adding to stream - 332 bytearray(b"\'\'")
# 330 23
# 330 258
# 330 259
# 330 260
# 330 266
# 330 267
# 330 268
# 330 269
# 330 270
# 330 278
# 330 284
# 330 311
# 330 312
# 330 313
# 330 316
# 330 319
# 330 325
# 330 348
# 330 329
# 330 None
# bc: 145  [353](9)|1| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'\x18\x18')
# 332 23
# 332 258
# 332 259
# 332 260
# 332 266
# 332 267
# 332 268
# 332 269
# 332 270
# 332 278
# 332 284
# 332 311
# 332 312
# 332 313
# 332 316
# 332 319
# 332 325
# 332 348
# 332 329
# 332 330
# 332 None
# bc: 144  [354](9)|2| 00000000  01000100   68 -> Found adding to stream - 68 bytearray(b'D')
# 290 23
# 290 258
# 290 259
# 290 260
# 290 266
# 290 267
# 290 268
# 290 269
# 290 270
# 290 278
# 290 284
# 290 311
# 290 291
# 290 290
# bc: 143  [355](9)|3| 00000001  00010110   278 -> Found adding to stream - 278 bytearray(b'\x18\x18')
# 68 23
# 68 258
# 68 176
# 68 132
# 68 124
# 68 68
# bc: 142  [356](9)|4| 00000001  00010111   279 -> Found adding to stream - 279 bytearray(b'\x18\x18')
# 278 23
# 278 258
# 278 259
# 278 260
# 278 266
# 278 267
# 278 268
# 278 269
# 278 270
# 278 278
# bc: 141  [357](9)|5| 00000000  00110001   49 -> Found adding to stream - 49 bytearray(b'1')
# 279 23
# 279 258
# 279 259
# 279 260
# 279 266
# 279 267
# 279 268
# 279 269
# 279 270
# 279 278
# 279 284
# 279 280
# 279 279
# bc: 140  [358](9)|6| 00000000  01101001   105 -> Found adding to stream - 105 bytearray(b'i')
# 49 23
# 49 258
# 49 176
# 49 132
# 49 124
# 49 68
# 49 24
# 49 44
# 49 49
# bc: 139  [359](9)|7| 00000000  10100111   167 -> Found adding to stream - 167 bytearray(b'\xa7')
# 105 23
# 105 258
# 105 176
# 105 132
# 105 124
# 105 68
# 105 81
# 105 123
# 105 122
# 105 92
# 105 None
# bc: 138  [360](9)|0| 00000000  01011100   92 -> Found adding to stream - 92 bytearray(b'\\')
# 167 23
# 167 258
# 167 176
# 167 132
# 167 173
# 167 None
# bc: 136  [361](9)|1| 00000000  10101101   173 -> Found adding to stream - 173 bytearray(b'\xad')
# 92 23
# 92 258
# 92 176
# 92 132
# 92 124
# 92 68
# 92 81
# 92 123
# 92 122
# 92 92
# bc: 135  [362](9)|2| 00000000  11101000   232 -> Found adding to stream - 232 bytearray(b'\xe8')
# 173 23
# 173 258
# 173 176
# 173 132
# 173 173
# bc: 134  [363](9)|3| 00000000  11101000   232 -> Found adding to stream - 232 bytearray(b'\xe8')
# 232 23
# 232 258
# 232 176
# 232 233
# 232 181
# 232 232
# bc: 133  [364](9)|4| 00000000  00001001   9 -> Found adding to stream - 9 bytearray(b'\t')
# 232 23
# 232 258
# 232 176
# 232 233
# 232 181
# 232 232
# bc: 132  [365](9)|5| 00000000  00001111   15 -> Found adding to stream - 15 bytearray(b'\x0f')
# 9 23
# 9 8
# 9 17
# 9 12
# 9 None
# bc: 131  [366](9)|6| 00000000  00001011   11 -> Found adding to stream - 11 bytearray(b'\x0b')
# 15 23
# 15 8
# 15 17
# 15 12
# 15 None
# bc: 130  [367](9)|7| 00000000  00010010   18 -> Found adding to stream - 18 bytearray(b'\x12')
# 11 23
# 11 8
# 11 17
# 11 12
# 11 9
# 11 None
# bc: 129  [368](9)|0| 00000000  00011110   30 -> Found adding to stream - 30 bytearray(b'\x1e')
# 18 23
# 18 8
# 18 17
# 18 None
# bc: 127  [369](9)|1| 00000000  01111010   122 -> Found adding to stream - 122 bytearray(b'z')
# 30 23
# 30 258
# 30 176
# 30 132
# 30 124
# 30 68
# 30 24
# 30 44
# 30 39
# 30 None
# bc: 126  [370](9)|2| 00000000  10110011   179 -> Found adding to stream - 179 bytearray(b'\xb3')
# 122 23
# 122 258
# 122 176
# 122 132
# 122 124
# 122 68
# 122 81
# 122 123
# 122 122
# bc: 125  [371](9)|3| 00000000  11100101   229 -> Found adding to stream - 229 bytearray(b'\xe5')
# 179 23
# 179 258
# 179 176
# 179 233
# 179 181
# 179 None
# bc: 124  [372](9)|4| 00000000  01010110   86 -> Found adding to stream - 86 bytearray(b'V')
# 229 23
# 229 258
# 229 176
# 229 233
# 229 181
# 229 232
# 229 None
# bc: 123  [373](9)|5| 00000000  10111111   191 -> Found adding to stream - 191 bytearray(b'\xbf')
# 86 23
# 86 258
# 86 176
# 86 132
# 86 124
# 86 68
# 86 81
# 86 123
# 86 122
# 86 92
# 86 None
# bc: 122  [374](9)|6| 00000000  10101011   171 -> Found adding to stream - 171 bytearray(b'\xab')
# 191 23
# 191 258
# 191 176
# 191 233
# 191 181
# 191 232
# 191 229
# 191 None
# bc: 121  [375](9)|7| 00000000  10101011   171 -> Found adding to stream - 171 bytearray(b'\xab')
# 171 23
# 171 258
# 171 176
# 171 132
# 171 173
# 171 167
# 171 None
# bc: 120  [376](9)|0| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'\x18\x18')
# 171 23
# 171 258
# 171 176
# 171 132
# 171 173
# 171 167
# 171 171
# bc: 118  [377](9)|1| 00000000  00110011   51 -> Found adding to stream - 51 bytearray(b'3')
# 290 23
# 290 258
# 290 259
# 290 260
# 290 266
# 290 267
# 290 268
# 290 269
# 290 270
# 290 278
# 290 284
# 290 311
# 290 291
# 290 290
# bc: 117  [378](9)|2| 00000000  00110011   51 -> Found adding to stream - 51 bytearray(b'3')
# 51 23
# 51 258
# 51 176
# 51 132
# 51 124
# 51 68
# 51 24
# 51 44
# 51 49
# 51 63
# 51 54
# 51 None
# bc: 116  [379](9)|3| 00000000  00001100   12 -> Found adding to stream - 12 bytearray(b'\x0c')
# 51 23
# 51 258
# 51 176
# 51 132
# 51 124
# 51 68
# 51 24
# 51 44
# 51 49
# 51 63
# 51 54
# 51 51
# bc: 115  [380](9)|4| 00000000  00001010   10 -> Found adding to stream - 10 bytearray(b'\n')
# 12 23
# 12 8
# 12 17
# 12 12
# bc: 114  [381](9)|5| 00000000  00001000   8 -> Found adding to stream - 8 bytearray(b'\x08')
# 10 23
# 10 8
# 10 17
# 10 12
# 10 9
# 10 11
# 10 None
# bc: 113  [382](9)|6| 00000000  00001010   10 -> Found adding to stream - 10 bytearray(b'\n')
# 8 23
# 8 8
# bc: 112  [383](9)|7| 00000000  00001010   10 -> Found adding to stream - 10 bytearray(b'\n')
# 10 23
# 10 8
# 10 17
# 10 12
# 10 9
# 10 11
# 10 10
# bc: 111  [384](9)|0| 00000001  01001001   329 -> Found adding to stream - 329 bytearray(b"\'\'")
# 10 23
# 10 8
# 10 17
# 10 12
# 10 9
# 10 11
# 10 10
# bc: 109  [385](9)|1| 00000000  00101101   45 -> Found adding to stream - 45 bytearray(b'-')
# 329 23
# 329 258
# 329 259
# 329 260
# 329 266
# 329 267
# 329 268
# 329 269
# 329 270
# 329 278
# 329 284
# 329 311
# 329 312
# 329 313
# 329 316
# 329 319
# 329 325
# 329 348
# 329 329
# bc: 108  [386](9)|2| 00000000  11010010   210 -> Found adding to stream - 210 bytearray(b'\xd2')
# 45 23
# 45 258
# 45 176
# 45 132
# 45 124
# 45 68
# 45 24
# 45 44
# 45 49
# 45 45
# bc: 107  [387](9)|3| 00000000  11010010   210 -> Found adding to stream - 210 bytearray(b'\xd2')
# 210 23
# 210 258
# 210 176
# 210 233
# 210 181
# 210 232
# 210 229
# 210 191
# 210 None
# bc: 106  [388](9)|4| 00000000  01101010   106 -> Found adding to stream - 106 bytearray(b'j')
# 210 23
# 210 258
# 210 176
# 210 233
# 210 181
# 210 232
# 210 229
# 210 191
# 210 210
# bc: 105  [389](9)|5| 00000000  01010000   80 -> Found adding to stream - 80 bytearray(b'P')
# 106 23
# 106 258
# 106 176
# 106 132
# 106 124
# 106 68
# 106 81
# 106 123
# 106 122
# 106 92
# 106 105
# 106 None
# bc: 104  [390](9)|6| 00000000  00110011   51 -> Found adding to stream - 51 bytearray(b'3')
# 80 23
# 80 258
# 80 176
# 80 132
# 80 124
# 80 68
# 80 81
# 80 None
# bc: 103  [391](9)|7| 00000000  01101010   106 -> Found adding to stream - 106 bytearray(b'j')
# 51 23
# 51 258
# 51 176
# 51 132
# 51 124
# 51 68
# 51 24
# 51 44
# 51 49
# 51 63
# 51 54
# 51 51
# bc: 102  [392](9)|0| 00000001  10001000   392 -> Not Found adding to stream- 106 bytearray(b'jj')
# 106 23
# 106 258
# 106 176
# 106 132
# 106 124
# 106 68
# 106 81
# 106 123
# 106 122
# 106 92
# 106 105
# 106 106
# bc: 100  [393](9)|1| 00000000  10100111   167 -> Found adding to stream - 167 bytearray(b'\xa7')
# 392 23
# 392 258
# 392 259
# 392 260
# 392 266
# 392 267
# 392 268
# 392 269
# 392 270
# 392 278
# 392 284
# 392 311
# 392 312
# 392 313
# 392 316
# 392 319
# 392 325
# 392 348
# 392 None
# bc: 99  [394](9)|2| 00000000  01110100   116 -> Found adding to stream - 116 bytearray(b't')
# 167 23
# 167 258
# 167 176
# 167 132
# 167 173
# 167 167
# bc: 98  [395](9)|3| 00000000  10101101   173 -> Found adding to stream - 173 bytearray(b'\xad')
# 116 23
# 116 258
# 116 176
# 116 132
# 116 124
# 116 68
# 116 81
# 116 123
# 116 122
# 116 92
# 116 105
# 116 106
# 116 None
# bc: 97  [396](9)|4| 00000000  10110101   181 -> Found adding to stream - 181 bytearray(b'\xb5')
# 173 23
# 173 258
# 173 176
# 173 132
# 173 173
# bc: 96  [397](9)|5| 00000000  00011110   30 -> Found adding to stream - 30 bytearray(b'\x1e')
# 181 23
# 181 258
# 181 176
# 181 233
# 181 181
# bc: 95  [398](9)|6| 00000000  00001111   15 -> Found adding to stream - 15 bytearray(b'\x0f')
# 30 23
# 30 258
# 30 176
# 30 132
# 30 124
# 30 68
# 30 24
# 30 44
# 30 39
# 30 30
# bc: 94  [399](9)|7| 00000000  00001111   15 -> Found adding to stream - 15 bytearray(b'\x0f')
# 15 23
# 15 8
# 15 17
# 15 12
# 15 15
# bc: 93  [400](9)|0| 00000000  00001001   9 -> Found adding to stream - 9 bytearray(b'\t')
# 15 23
# 15 8
# 15 17
# 15 12
# 15 15
# bc: 91  [401](9)|1| 00000000  00001110   14 -> Found adding to stream - 14 bytearray(b'\x0e')
# 9 23
# 9 8
# 9 17
# 9 12
# 9 9
# bc: 90  [402](9)|2| 00000000  00001110   14 -> Found adding to stream - 14 bytearray(b'\x0e')
# 14 23
# 14 8
# 14 17
# 14 12
# 14 15
# 14 None
# bc: 89  [403](9)|3| 00000001  00001100   268 -> Found adding to stream - 268 bytearray(b'\x84\x84')
# 14 23
# 14 8
# 14 17
# 14 12
# 14 15
# 14 14
# bc: 88  [404](9)|4| 00000001  00110101   309 -> Found adding to stream - 309 bytearray(b'||')
# 268 23
# 268 258
# 268 259
# 268 260
# 268 266
# 268 267
# 268 268
# bc: 87  [405](9)|5| 00000001  00000010   258 -> Found adding to stream - 258 bytearray(b'\x17\x17')
# 309 23
# 309 258
# 309 259
# 309 260
# 309 266
# 309 267
# 309 268
# 309 269
# 309 270
# 309 278
# 309 284
# 309 311
# 309 291
# 309 292
# 309 None
# bc: 86  [406](9)|6| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b',,')
# 258 23
# 258 258
# bc: 85  [407](9)|7| 00000001  00111001   313 -> Found adding to stream - 313 bytearray(b'QQ')
# 273 23
# 273 258
# 273 259
# 273 260
# 273 266
# 273 267
# 273 268
# 273 269
# 273 270
# 273 278
# 273 276
# 273 273
# bc: 84  [408](9)|0| 00000001  00001111   271 -> Found adding to stream - 271 bytearray(b'||')
# 313 23
# 313 258
# 313 259
# 313 260
# 313 266
# 313 267
# 313 268
# 313 269
# 313 270
# 313 278
# 313 284
# 313 311
# 313 312
# 313 313
# bc: 82  [409](9)|1| 00000001  10011001   409 -> Not Found adding to stream- 271 bytearray(b'|||')
# 271 23
# 271 258
# 271 259
# 271 260
# 271 266
# 271 267
# 271 268
# 271 269
# 271 270
# 271 278
# 271 276
# 271 273
# 271 None
# bc: 81  [410](9)|2| 00000001  10011010   410 -> Not Found adding to stream- 409 bytearray(b'\xa7\xa7\xa7')
# 409 23
# 409 258
# 409 259
# 409 260
# 409 266
# 409 267
# 409 268
# 409 269
# 409 270
# 409 278
# 409 284
# 409 311
# 409 312
# 409 313
# 409 316
# 409 319
# 409 325
# 409 348
# 409 392
# 409 None
# bc: 80  [411](9)|3| 00000001  10010110   406 -> Found adding to stream - 406 bytearray(b'\xa7\xa7')
# 410 23
# 410 258
# 410 259
# 410 260
# 410 266
# 410 267
# 410 268
# 410 269
# 410 270
# 410 278
# 410 284
# 410 311
# 410 312
# 410 313
# 410 316
# 410 319
# 410 325
# 410 348
# 410 392
# 410 409
# 410 None
# bc: 79  [412](9)|4| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b',,')
# 406 23
# 406 258
# 406 259
# 406 260
# 406 266
# 406 267
# 406 268
# 406 269
# 406 270
# 406 278
# 406 284
# 406 311
# 406 312
# 406 313
# 406 316
# 406 319
# 406 325
# 406 348
# 406 392
# 406 409
# 406 None
# bc: 78  [413](9)|5| 00000000  01010001   81 -> Found adding to stream - 81 bytearray(b'Q')
# 273 23
# 273 258
# 273 259
# 273 260
# 273 266
# 273 267
# 273 268
# 273 269
# 273 270
# 273 278
# 273 276
# 273 273
# bc: 77  [414](9)|6| 00000001  00011110   286 -> Found adding to stream - 286 bytearray(b'\x18\x18')
# 81 23
# 81 258
# 81 176
# 81 132
# 81 124
# 81 68
# 81 81
# bc: 76  [415](9)|7| 00000001  00011101   285 -> Found adding to stream - 285 bytearray(b'\x18\x18')
# 286 23
# 286 258
# 286 259
# 286 260
# 286 266
# 286 267
# 286 268
# 286 269
# 286 270
# 286 278
# 286 284
# 286 311
# 286 291
# 286 290
# 286 None
# bc: 75  [416](9)|0| 00000001  10100000   416 -> Not Found adding to stream- 285 bytearray(b'\x18\x18\x18')
# 285 23
# 285 258
# 285 259
# 285 260
# 285 266
# 285 267
# 285 268
# 285 269
# 285 270
# 285 278
# 285 284
# 285 311
# 285 291
# 285 290
# 285 286
# 285 None
# bc: 73  [417](9)|1| 00000001  00011111   287 -> Found adding to stream - 287 bytearray(b'\x18\x18')
# 416 23
# 416 258
# 416 259
# 416 260
# 416 266
# 416 267
# 416 268
# 416 269
# 416 270
# 416 278
# 416 284
# 416 311
# 416 312
# 416 313
# 416 316
# 416 319
# 416 325
# 416 348
# 416 392
# 416 409
# 416 410
# 416 None
# bc: 72  [418](9)|2| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x18\x18')
# 287 23
# 287 258
# 287 259
# 287 260
# 287 266
# 287 267
# 287 268
# 287 269
# 287 270
# 287 278
# 287 284
# 287 311
# 287 291
# 287 290
# 287 286
# 287 None
# bc: 71  [419](9)|3| 00000001  00011110   286 -> Found adding to stream - 286 bytearray(b'\x18\x18')
# 280 23
# 280 258
# 280 259
# 280 260
# 280 266
# 280 267
# 280 268
# 280 269
# 280 270
# 280 278
# 280 284
# 280 280
# bc: 70  [420](9)|4| 00000001  00011111   287 -> Found adding to stream - 287 bytearray(b'\x18\x18')
# 286 23
# 286 258
# 286 259
# 286 260
# 286 266
# 286 267
# 286 268
# 286 269
# 286 270
# 286 278
# 286 284
# 286 311
# 286 291
# 286 290
# 286 286
# bc: 69  [421](9)|5| 00000001  00100100   292 -> Found adding to stream - 292 bytearray(b'\x17\x17')
# 287 23
# 287 258
# 287 259
# 287 260
# 287 266
# 287 267
# 287 268
# 287 269
# 287 270
# 287 278
# 287 284
# 287 311
# 287 291
# 287 290
# 287 286
# 287 287
# bc: 68  [422](9)|6| 00000001  00100101   293 -> Found adding to stream - 293 bytearray(b'\x17\x17')
# 292 23
# 292 258
# 292 259
# 292 260
# 292 266
# 292 267
# 292 268
# 292 269
# 292 270
# 292 278
# 292 284
# 292 311
# 292 291
# 292 292
# bc: 67  [423](9)|7| 00000001  00000111   263 -> Found adding to stream - 263 bytearray(b'||')
# 293 23
# 293 258
# 293 259
# 293 260
# 293 266
# 293 267
# 293 268
# 293 269
# 293 270
# 293 278
# 293 284
# 293 311
# 293 291
# 293 292
# 293 309
# 293 None
# bc: 66  [424](9)|0| 00000001  00000110   262 -> Found adding to stream - 262 bytearray(b'||')
# 263 23
# 263 258
# 263 259
# 263 260
# 263 266
# 263 265
# 263 262
# 263 263
# bc: 64  [425](9)|1| 00000001  00000110   262 -> Found adding to stream - 262 bytearray(b'||')
# 262 23
# 262 258
# 262 259
# 262 260
# 262 266
# 262 265
# 262 262
# bc: 63  [426](9)|2| 00000000  10101011   171 -> Found adding to stream - 171 bytearray(b'\xab')
# 262 23
# 262 258
# 262 259
# 262 260
# 262 266
# 262 265
# 262 262
# bc: 62  [427](9)|3| 00000000  10100111   167 -> Found adding to stream - 167 bytearray(b'\xa7')
# 171 23
# 171 258
# 171 176
# 171 132
# 171 173
# 171 167
# 171 171
# bc: 61  [428](9)|4| 00000000  01010110   86 -> Found adding to stream - 86 bytearray(b'V')
# 167 23
# 167 258
# 167 176
# 167 132
# 167 173
# 167 167
# bc: 60  [429](9)|5| 00000000  10110011   179 -> Found adding to stream - 179 bytearray(b'\xb3')
# 86 23
# 86 258
# 86 176
# 86 132
# 86 124
# 86 68
# 86 81
# 86 123
# 86 122
# 86 92
# 86 86
# bc: 59  [430](9)|6| 00000000  01111010   122 -> Found adding to stream - 122 bytearray(b'z')
# 179 23
# 179 258
# 179 176
# 179 233
# 179 181
# 179 179
# bc: 58  [431](9)|7| 00000000  00111111   63 -> Found adding to stream - 63 bytearray(b'?')
# 122 23
# 122 258
# 122 176
# 122 132
# 122 124
# 122 68
# 122 81
# 122 123
# 122 122
# bc: 57  [432](9)|0| 00000000  01111010   122 -> Found adding to stream - 122 bytearray(b'z')
# 63 23
# 63 258
# 63 176
# 63 132
# 63 124
# 63 68
# 63 24
# 63 44
# 63 49
# 63 63
# bc: 55  [433](9)|1| 00000001  10110001   433 -> Not Found adding to stream- 122 bytearray(b'zz')
# 122 23
# 122 258
# 122 176
# 122 132
# 122 124
# 122 68
# 122 81
# 122 123
# 122 122
# bc: 54  [434](9)|2| 00000000  10101000   168 -> Found adding to stream - 168 bytearray(b'\xa8')
# 433 23
# 433 258
# 433 259
# 433 260
# 433 266
# 433 267
# 433 268
# 433 269
# 433 270
# 433 278
# 433 284
# 433 311
# 433 312
# 433 313
# 433 316
# 433 319
# 433 325
# 433 348
# 433 392
# 433 409
# 433 410
# 433 416
# 433 None
# bc: 53  [435](9)|3| 00000000  01011100   92 -> Found adding to stream - 92 bytearray(b'\\')
# 168 23
# 168 258
# 168 176
# 168 132
# 168 173
# 168 167
# 168 171
# 168 None
# bc: 52  [436](9)|4| 00000000  01000111   71 -> Found adding to stream - 71 bytearray(b'G')
# 92 23
# 92 258
# 92 176
# 92 132
# 92 124
# 92 68
# 92 81
# 92 123
# 92 122
# 92 92
# bc: 51  [437](9)|5| 00000000  11110110   246 -> Found adding to stream - 246 bytearray(b'\xf6')
# 71 23
# 71 258
# 71 176
# 71 132
# 71 124
# 71 68
# 71 81
# 71 80
# 71 None
# bc: 50  [438](9)|6| 00000001  00000111   263 -> Found adding to stream - 263 bytearray(b'||')
# 246 23
# 246 258
# 246 176
# 246 233
# 246 None
# bc: 49  [439](9)|7| 00000001  00000011   259 -> Found adding to stream - 259 bytearray(b'\x84\x84')
# 263 23
# 263 258
# 263 259
# 263 260
# 263 266
# 263 265
# 263 262
# 263 263
# bc: 48  [440](9)|0| 00000001  00100111   295 -> Found adding to stream - 295 bytearray(b'||')
# 259 23
# 259 258
# 259 259
# bc: 46  [441](9)|1| 00000001  00111000   312 -> Found adding to stream - 312 bytearray(b'\x18\x18')
# 295 23
# 295 258
# 295 259
# 295 260
# 295 266
# 295 267
# 295 268
# 295 269
# 295 270
# 295 278
# 295 284
# 295 311
# 295 291
# 295 292
# 295 309
# 295 293
# 295 None
# bc: 45  [442](9)|2| 00000001  00100110   294 -> Found adding to stream - 294 bytearray(b'\x18\x18')
# 312 23
# 312 258
# 312 259
# 312 260
# 312 266
# 312 267
# 312 268
# 312 269
# 312 270
# 312 278
# 312 284
# 312 311
# 312 312
# bc: 44  [443](9)|3| 00000001  00111000   312 -> Found adding to stream - 312 bytearray(b'\x18\x18')
# 294 23
# 294 258
# 294 259
# 294 260
# 294 266
# 294 267
# 294 268
# 294 269
# 294 270
# 294 278
# 294 284
# 294 311
# 294 291
# 294 292
# 294 309
# 294 293
# 294 295
# 294 None
# bc: 43  [444](9)|4| 00000001  00010000   272 -> Found adding to stream - 272 bytearray(b'||')
# 312 23
# 312 258
# 312 259
# 312 260
# 312 266
# 312 267
# 312 268
# 312 269
# 312 270
# 312 278
# 312 284
# 312 311
# 312 312
# bc: 42  [445](9)|5| 00000000  01111100   124 -> Found adding to stream - 124 bytearray(b'|')
# 272 23
# 272 258
# 272 259
# 272 260
# 272 266
# 272 267
# 272 268
# 272 269
# 272 270
# 272 278
# 272 276
# 272 273
# 272 271
# 272 None
# bc: 41  [446](9)|6| 00000001  01010101   341 -> Found adding to stream - 341 bytearray(b'\x18\x18')
# 124 23
# 124 258
# 124 176
# 124 132
# 124 124
# bc: 40  [447](9)|7| 00000001  10111111   447 -> Not Found adding to stream- 341 bytearray(b'\x18\x18\x18')
# 341 23
# 341 258
# 341 259
# 341 260
# 341 266
# 341 267
# 341 268
# 341 269
# 341 270
# 341 278
# 341 284
# 341 311
# 341 312
# 341 313
# 341 316
# 341 319
# 341 325
# 341 348
# 341 329
# 341 330
# 341 332
# 341 None
# bc: 39  [448](9)|0| 00000001  00010101   277 -> Found adding to stream - 277 bytearray(b'||')
# 447 23
# 447 258
# 447 259
# 447 260
# 447 266
# 447 267
# 447 268
# 447 269
# 447 270
# 447 278
# 447 284
# 447 311
# 447 312
# 447 313
# 447 316
# 447 319
# 447 325
# 447 348
# 447 392
# 447 409
# 447 410
# 447 416
# 447 433
# 447 None
# bc: 37  [449](9)|1| 00000001  01100100   356 -> Found adding to stream - 356 bytearray(b'\xa7\xa7')
# 277 23
# 277 258
# 277 259
# 277 260
# 277 266
# 277 267
# 277 268
# 277 269
# 277 270
# 277 278
# 277 276
# 277 None
# bc: 36  [450](9)|2| 00000001  00010110   278 -> Found adding to stream - 278 bytearray(b'\x18\x18')
# 356 23
# 356 258
# 356 259
# 356 260
# 356 266
# 356 267
# 356 268
# 356 269
# 356 270
# 356 278
# 356 284
# 356 311
# 356 312
# 356 313
# 356 316
# 356 319
# 356 325
# 356 348
# 356 392
# 356 None
# bc: 35  [451](9)|3| 00000001  00011001   281 -> Found adding to stream - 281 bytearray(b'\x18\x18')
# 278 23
# 278 258
# 278 259
# 278 260
# 278 266
# 278 267
# 278 268
# 278 269
# 278 270
# 278 278
# bc: 34  [452](9)|4| 00000000  00011000   24 -> Found adding to stream - 24 bytearray(b'\x18')
# 281 23
# 281 258
# 281 259
# 281 260
# 281 266
# 281 267
# 281 268
# 281 269
# 281 270
# 281 278
# 281 284
# 281 280
# 281 None
# bc: 33  [453](9)|5| 00000001  01011111   351 -> Found adding to stream - 351 bytearray(b'\x18\x18')
# 24 23
# 24 258
# 24 176
# 24 132
# 24 124
# 24 68
# 24 24
# bc: 32  [454](9)|6| 00000001  11000110   454 -> Not Found adding to stream- 351 bytearray(b'\x18\x18\x18')
# 351 23
# 351 258
# 351 259
# 351 260
# 351 266
# 351 267
# 351 268
# 351 269
# 351 270
# 351 278
# 351 284
# 351 311
# 351 312
# 351 313
# 351 316
# 351 319
# 351 325
# 351 348
# 351 392
# 351 356
# 351 None
# bc: 31  [455](9)|7| 00000001  01100000   352 -> Found adding to stream - 352 bytearray(b'\x18\x18')
# 454 23
# 454 258
# 454 259
# 454 260
# 454 266
# 454 267
# 454 268
# 454 269
# 454 270
# 454 278
# 454 284
# 454 311
# 454 312
# 454 313
# 454 316
# 454 319
# 454 325
# 454 348
# 454 392
# 454 409
# 454 410
# 454 416
# 454 433
# 454 447
# 454 None
# bc: 30  [456](9)|0| 00000000  00001100   12 -> Found adding to stream - 12 bytearray(b'\x0c')
# 352 23
# 352 258
# 352 259
# 352 260
# 352 266
# 352 267
# 352 268
# 352 269
# 352 270
# 352 278
# 352 284
# 352 311
# 352 312
# 352 313
# 352 316
# 352 319
# 352 325
# 352 348
# 352 392
# 352 356
# 352 351
# 352 None
# bc: 28  [457](9)|1| 00000000  00011000   24 -> Found adding to stream - 24 bytearray(b'\x18')
# 12 23
# 12 8
# 12 17
# 12 12
# bc: 27  [458](9)|2| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'\xa7\xa7')
# 24 23
# 24 258
# 24 176
# 24 132
# 24 124
# 24 68
# 24 24
# bc: 26  [459](9)|3| 00000001  00100101   293 -> Found adding to stream - 293 bytearray(b'\x18\x18')
# 276 23
# 276 258
# 276 259
# 276 260
# 276 266
# 276 267
# 276 268
# 276 269
# 276 270
# 276 278
# 276 276
# bc: 25  [460](9)|4| 00000001  10111011   443 -> Found adding to stream - 443 bytearray(b'||')
# 293 23
# 293 258
# 293 259
# 293 260
# 293 266
# 293 267
# 293 268
# 293 269
# 293 270
# 293 278
# 293 284
# 293 311
# 293 291
# 293 292
# 293 309
# 293 293
# bc: 24  [461](9)|5| 00000001  00110111   311 -> Found adding to stream - 311 bytearray(b'\x18\x18')
# 443 23
# 443 258
# 443 259
# 443 260
# 443 266
# 443 267
# 443 268
# 443 269
# 443 270
# 443 278
# 443 284
# 443 311
# 443 312
# 443 313
# 443 316
# 443 319
# 443 325
# 443 348
# 443 392
# 443 409
# 443 410
# 443 416
# 443 433
# 443 447
# 443 None
# bc: 23  [462](9)|6| 00000001  00111100   316 -> Found adding to stream - 316 bytearray(b'||')
# 311 23
# 311 258
# 311 259
# 311 260
# 311 266
# 311 267
# 311 268
# 311 269
# 311 270
# 311 278
# 311 284
# 311 311
# bc: 22  [463](9)|7| 00000001  00010011   275 -> Found adding to stream - 275 bytearray(b',,')
# 316 23
# 316 258
# 316 259
# 316 260
# 316 266
# 316 267
# 316 268
# 316 269
# 316 270
# 316 278
# 316 284
# 316 311
# 316 312
# 316 313
# 316 316
# bc: 21  [464](9)|0| 00000001  00010100   276 -> Found adding to stream - 276 bytearray(b'\xa7\xa7')
# 275 23
# 275 258
# 275 259
# 275 260
# 275 266
# 275 267
# 275 268
# 275 269
# 275 270
# 275 278
# 275 276
# 275 273
# 275 274
# 275 None
# bc: 19  [465](9)|1| 00000000  11010111   215 -> Found adding to stream - 215 bytearray(b'\xd7')
# 276 23
# 276 258
# 276 259
# 276 260
# 276 266
# 276 267
# 276 268
# 276 269
# 276 270
# 276 278
# 276 276
# bc: 18  [466](9)|2| 00000000  00001000   8 -> Found adding to stream - 8 bytearray(b'\x08')
# 215 23
# 215 258
# 215 176
# 215 233
# 215 181
# 215 232
# 215 229
# 215 191
# 215 210
# 215 None
# bc: 17  [467](9)|3| 00000001  01010111   343 -> Found adding to stream - 343 bytearray(b'\x18\x18')
# 8 23
# 8 8
# bc: 16  [468](9)|4| 00000001  01111001   377 -> Found adding to stream - 377 bytearray(b'\x18\x18')
# 343 23
# 343 258
# 343 259
# 343 260
# 343 266
# 343 267
# 343 268
# 343 269
# 343 270
# 343 278
# 343 284
# 343 311
# 343 312
# 343 313
# 343 316
# 343 319
# 343 325
# 343 348
# 343 329
# 343 330
# 343 332
# 343 341
# 343 None
# bc: 15  [469](9)|5| 00000001  01011010   346 -> Found adding to stream - 346 bytearray(b'\x18\x18')
# 377 23
# 377 258
# 377 259
# 377 260
# 377 266
# 377 267
# 377 268
# 377 269
# 377 270
# 377 278
# 377 284
# 377 311
# 377 312
# 377 313
# 377 316
# 377 319
# 377 325
# 377 348
# 377 392
# 377 356
# 377 None
# bc: 14  [470](9)|6| 00000001  01001000   328 -> Found adding to stream - 328 bytearray(b"\'\'")
# 346 23
# 346 258
# 346 259
# 346 260
# 346 266
# 346 267
# 346 268
# 346 269
# 346 270
# 346 278
# 346 284
# 346 311
# 346 312
# 346 313
# 346 316
# 346 319
# 346 325
# 346 348
# 346 329
# 346 330
# 346 332
# 346 341
# 346 343
# 346 None
# bc: 13  [471](9)|7| 00000001  11000111   455 -> Found adding to stream - 455 bytearray(b'\x18\x18')
# 328 23
# 328 258
# 328 259
# 328 260
# 328 266
# 328 267
# 328 268
# 328 269
# 328 270
# 328 278
# 328 284
# 328 311
# 328 312
# 328 313
# 328 316
# 328 319
# 328 325
# 328 348
# 328 329
# 328 None
# bc: 12  [472](9)|0| 00000001  01001011   331 -> Found adding to stream - 331 bytearray(b'\x18\x18')
# 455 23
# 455 258
# 455 259
# 455 260
# 455 266
# 455 267
# 455 268
# 455 269
# 455 270
# 455 278
# 455 284
# 455 311
# 455 312
# 455 313
# 455 316
# 455 319
# 455 325
# 455 348
# 455 392
# 455 409
# 455 410
# 455 416
# 455 433
# 455 447
# 455 454
# 455 None
# bc: 10  [473](9)|1| 00000001  00011000   280 -> Found adding to stream - 280 bytearray(b'\x18\x18')
# 331 23
# 331 258
# 331 259
# 331 260
# 331 266
# 331 267
# 331 268
# 331 269
# 331 270
# 331 278
# 331 284
# 331 311
# 331 312
# 331 313
# 331 316
# 331 319
# 331 325
# 331 348
# 331 329
# 331 330
# 331 332
# 331 None
# bc: 9  [474](9)|2| 00000001  10111111   447 -> Found adding to stream - 447 bytearray(b'\x18\x18')
# 280 23
# 280 258
# 280 259
# 280 260
# 280 266
# 280 267
# 280 268
# 280 269
# 280 270
# 280 278
# 280 284
# 280 280
# bc: 8  [475](9)|3| 00000001  00100010   290 -> Found adding to stream - 290 bytearray(b'\x18\x18')
# 447 23
# 447 258
# 447 259
# 447 260
# 447 266
# 447 267
# 447 268
# 447 269
# 447 270
# 447 278
# 447 284
# 447 311
# 447 312
# 447 313
# 447 316
# 447 319
# 447 325
# 447 348
# 447 392
# 447 409
# 447 410
# 447 416
# 447 433
# 447 447
# bc: 7  [476](9)|4| 00000000  11010010   210 -> Found adding to stream - 210 bytearray(b'\xd2')
# 290 23
# 290 258
# 290 259
# 290 260
# 290 266
# 290 267
# 290 268
# 290 269
# 290 270
# 290 278
# 290 284
# 290 311
# 290 291
# 290 290
# bc: 6  [477](9)|5| 00000000  11011010   218 -> Found adding to stream - 218 bytearray(b'\xda')
# 210 23
# 210 258
# 210 176
# 210 233
# 210 181
# 210 232
# 210 229
# 210 191
# 210 210
# bc: 5  [478](9)|6| 00000000  01011100   92 -> Found adding to stream - 92 bytearray(b'\\')
# 218 23
# 218 258
# 218 176
# 218 233
# 218 181
# 218 232
# 218 229
# 218 191
# 218 210
# 218 215
# 218 None
# bc: 4  [479](9)|7| 00000000  10101000   168 -> Found adding to stream - 168 bytearray(b'\xa8')
# 92 23
# 92 258
# 92 176
# 92 132
# 92 124
# 92 68
# 92 81
# 92 123
# 92 122
# 92 92
# bc: 3  [480](9)|0| 00000000  11101000   232 -> Found adding to stream - 232 bytearray(b'\xe8')
# 168 23
# 168 258
# 168 176
# 168 132
# 168 173
# 168 167
# 168 171
# 168 168
# bc: 1  [481](9)|1| 00000000  00100001   33 -> Found adding to stream - 33 bytearray(b'!')
# 232 23
# 232 258
# 232 176
# 232 233
# 232 181
# 232 232
# bc: 255  [482](9)|2| 00000001  01101110   366 -> Found adding to stream - 366 bytearray(b'\x18\x18')
# 33 23
# 33 258
# 33 176
# 33 132
# 33 124
# 33 68
# 33 24
# 33 44
# 33 39
# 33 30
# 33 None
# bc: 254  [483](9)|3| 00000001  01101111   367 -> Found adding to stream - 367 bytearray(b'\x18\x18')
# 366 23
# 366 258
# 366 259
# 366 260
# 366 266
# 366 267
# 366 268
# 366 269
# 366 270
# 366 278
# 366 284
# 366 311
# 366 312
# 366 313
# 366 316
# 366 319
# 366 325
# 366 348
# 366 392
# 366 356
# 366 377
# 366 None
# bc: 253  [484](9)|4| 00000000  00100001   33 -> Found adding to stream - 33 bytearray(b'!')
# 367 23
# 367 258
# 367 259
# 367 260
# 367 266
# 367 267
# 367 268
# 367 269
# 367 270
# 367 278
# 367 284
# 367 311
# 367 312
# 367 313
# 367 316
# 367 319
# 367 325
# 367 348
# 367 392
# 367 356
# 367 377
# 367 366
# 367 None
# bc: 252  [485](9)|5| 00000000  01000010   66 -> Found adding to stream - 66 bytearray(b'B')
# 33 23
# 33 258
# 33 176
# 33 132
# 33 124
# 33 68
# 33 24
# 33 44
# 33 39
# 33 30
# 33 33
# bc: 251  [486](9)|6| 00000001  00110001   305 -> Found adding to stream - 305 bytearray(b'\x18\x18')
# 66 23
# 66 258
# 66 176
# 66 132
# 66 124
# 66 68
# 66 24
# 66 44
# 66 49
# 66 63
# 66 None
# bc: 250  [487](9)|7| 00000000  01011100   92 -> Found adding to stream - 92 bytearray(b'\\')
# 305 23
# 305 258
# 305 259
# 305 260
# 305 266
# 305 267
# 305 268
# 305 269
# 305 270
# 305 278
# 305 284
# 305 311
# 305 291
# 305 292
# 305 309
# 305 293
# 305 295
# 305 None
# bc: 249  [488](9)|0| 00000000  10111000   184 -> Found adding to stream - 184 bytearray(b'\xb8')
# 92 23
# 92 258
# 92 176
# 92 132
# 92 124
# 92 68
# 92 81
# 92 123
# 92 122
# 92 92
# bc: 247  [489](9)|1| 00000000  10100010   162 -> Found adding to stream - 162 bytearray(b'\xa2')
# 184 23
# 184 258
# 184 176
# 184 233
# 184 181
# 184 232
# 184 229
# 184 191
# 184 None
# bc: 246  [490](9)|2| 00000001  01111000   376 -> Found adding to stream - 376 bytearray(b'!!')
# 162 23
# 162 258
# 162 176
# 162 132
# 162 173
# 162 167
# 162 None
# bc: 245  [491](9)|3| 00000000  00110001   49 -> Found adding to stream - 49 bytearray(b'1')
# 376 23
# 376 258
# 376 259
# 376 260
# 376 266
# 376 267
# 376 268
# 376 269
# 376 270
# 376 278
# 376 284
# 376 311
# 376 312
# 376 313
# 376 316
# 376 319
# 376 325
# 376 348
# 376 392
# 376 356
# 376 377
# 376 366
# 376 367
# 376 None
# bc: 244  [492](9)|4| 00000001  01111010   378 -> Found adding to stream - 378 bytearray(b'\x18\x18')
# 49 23
# 49 258
# 49 176
# 49 132
# 49 124
# 49 68
# 49 24
# 49 44
# 49 49
# bc: 243  [493](9)|5| 00000001  11000100   452 -> Found adding to stream - 452 bytearray(b'\x18\x18')
# 378 23
# 378 258
# 378 259
# 378 260
# 378 266
# 378 267
# 378 268
# 378 269
# 378 270
# 378 278
# 378 284
# 378 311
# 378 312
# 378 313
# 378 316
# 378 319
# 378 325
# 378 348
# 378 392
# 378 356
# 378 377
# 378 None
# bc: 242  [494](9)|6| 00000001  10100000   416 -> Found adding to stream - 416 bytearray(b'\xa8\xa8')
# 452 23
# 452 258
# 452 259
# 452 260
# 452 266
# 452 267
# 452 268
# 452 269
# 452 270
# 452 278
# 452 284
# 452 311
# 452 312
# 452 313
# 452 316
# 452 319
# 452 325
# 452 348
# 452 392
# 452 409
# 452 410
# 452 416
# 452 433
# 452 447
# 452 454
# 452 None
# bc: 241  [495](9)|7| 00000000  00011000   24 -> Found adding to stream - 24 bytearray(b'\x18')
# 416 23
# 416 258
# 416 259
# 416 260
# 416 266
# 416 267
# 416 268
# 416 269
# 416 270
# 416 278
# 416 284
# 416 311
# 416 312
# 416 313
# 416 316
# 416 319
# 416 325
# 416 348
# 416 392
# 416 409
# 416 410
# 416 416
# bc: 240  [496](9)|0| 00000000  00001010   10 -> Found adding to stream - 10 bytearray(b'\n')
# 24 23
# 24 258
# 24 176
# 24 132
# 24 124
# 24 68
# 24 24
# bc: 238  [497](9)|1| 00000001  10000101   389 -> Found adding to stream - 389 bytearray(b'\x18\x18')
# 10 23
# 10 8
# 10 17
# 10 12
# 10 9
# 10 11
# 10 10
# bc: 237  [498](9)|2| 00000000  00110011   51 -> Found adding to stream - 51 bytearray(b'3')
# 389 23
# 389 258
# 389 259
# 389 260
# 389 266
# 389 267
# 389 268
# 389 269
# 389 270
# 389 278
# 389 284
# 389 311
# 389 312
# 389 313
# 389 316
# 389 319
# 389 325
# 389 348
# 389 392
# 389 356
# 389 377
# 389 378
# 389 None
# bc: 236  [499](9)|3| 00000001  00011100   284 -> Found adding to stream - 284 bytearray(b'\x18\x18')
# 51 23
# 51 258
# 51 176
# 51 132
# 51 124
# 51 68
# 51 24
# 51 44
# 51 49
# 51 63
# 51 54
# 51 51
# bc: 235  [500](9)|4| 00000000  00110011   51 -> Found adding to stream - 51 bytearray(b'3')
# 284 23
# 284 258
# 284 259
# 284 260
# 284 266
# 284 267
# 284 268
# 284 269
# 284 270
# 284 278
# 284 284
# bc: 234  [501](9)|5| 00000001  01100111   359 -> Found adding to stream - 359 bytearray(b'\x18\x18')
# 51 23
# 51 258
# 51 176
# 51 132
# 51 124
# 51 68
# 51 24
# 51 44
# 51 49
# 51 63
# 51 54
# 51 51
# bc: 233  [502](9)|6| 00000000  01100100   100 -> Found adding to stream - 100 bytearray(b'd')
# 359 23
# 359 258
# 359 259
# 359 260
# 359 266
# 359 267
# 359 268
# 359 269
# 359 270
# 359 278
# 359 284
# 359 311
# 359 312
# 359 313
# 359 316
# 359 319
# 359 325
# 359 348
# 359 392
# 359 356
# 359 377
# 359 366
# 359 None
# bc: 232  [503](9)|7| 00000000  10101111   175 -> Found adding to stream - 175 bytearray(b'\xaf')
# 100 23
# 100 258
# 100 176
# 100 132
# 100 124
# 100 68
# 100 81
# 100 123
# 100 122
# 100 92
# 100 105
# 100 None
# bc: 231  [504](9)|0| 00000000  01111010   122 -> Found adding to stream - 122 bytearray(b'z')
# 175 23
# 175 258
# 175 176
# 175 132
# 175 173
# 175 None
# bc: 229  [505](9)|1| 00000000  00011110   30 -> Found adding to stream - 30 bytearray(b'\x1e')
# 122 23
# 122 258
# 122 176
# 122 132
# 122 124
# 122 68
# 122 81
# 122 123
# 122 122
# bc: 228  [506](9)|2| 00000000  00100001   33 -> Found adding to stream - 33 bytearray(b'!')
# 30 23
# 30 258
# 30 176
# 30 132
# 30 124
# 30 68
# 30 24
# 30 44
# 30 39
# 30 30
# bc: 227  [507](9)|3| 00000001  11111011   507 -> Not Found adding to stream- 33 bytearray(b'!!')
# 33 23
# 33 258
# 33 176
# 33 132
# 33 124
# 33 68
# 33 24
# 33 44
# 33 39
# 33 30
# 33 33
# bc: 226  [508](9)|4| 00000000  00001111   15 -> Found adding to stream - 15 bytearray(b'\x0f')
# 507 23
# 507 258
# 507 259
# 507 260
# 507 266
# 507 267
# 507 268
# 507 269
# 507 270
# 507 278
# 507 284
# 507 311
# 507 312
# 507 313
# 507 316
# 507 319
# 507 325
# 507 348
# 507 392
# 507 409
# 507 410
# 507 416
# 507 433
# 507 447
# 507 454
# 507 455
# 507 None
# bc: 225  [509](9)|5| 00000001  10010011   403 -> Found adding to stream - 403 bytearray(b',,')
# 15 23
# 15 8
# 15 17
# 15 12
# 15 15
# bc: 224  [510](9)|6| 00000001  00001011   267 -> Found adding to stream - 267 bytearray(b'\x84\x84')
# 403 23
# 403 258
# 403 259
# 403 260
# 403 266
# 403 267
# 403 268
# 403 269
# 403 270
# 403 278
# 403 284
# 403 311
# 403 312
# 403 313
# 403 316
# 403 319
# 403 325
# 403 348
# 403 392
# 403 409
# 403 406
# 403 None
# bc: 223  [511](9)|7| 00000001  10101001   425 -> Found adding to stream - 425 bytearray(b'\xa8\xa8')
# 267 23
# 267 258
# 267 259
# 267 260
# 267 266
# 267 267
# TableIndex maxed out!  511
# Increased to:  1023
# bc: 222  [512](10)|0| 00000001  00010000   272 -> Found adding to stream - 272 bytearray(b'||')
# 425 23
# 425 258
# 425 259
# 425 260
# 425 266
# 425 267
# 425 268
# 425 269
# 425 270
# 425 278
# 425 284
# 425 311
# 425 312
# 425 313
# 425 316
# 425 319
# 425 325
# 425 348
# 425 392
# 425 409
# 425 410
# 425 416
# 425 433
# 425 None
# bc: 220  [513](10)|2| 00000001  00010001   273 -> Found adding to stream - 273 bytearray(b',,')
# 272 23
# 272 258
# 272 259
# 272 260
# 272 266
# 272 267
# 272 268
# 272 269
# 272 270
# 272 278
# 272 276
# 272 273
# 272 271
# 272 272
# bc: 219  [514](10)|4| 00000001  10111101   445 -> Found adding to stream - 445 bytearray(b'\x18\x18')
# 273 23
# 273 258
# 273 259
# 273 260
# 273 266
# 273 267
# 273 268
# 273 269
# 273 270
# 273 278
# 273 276
# 273 273
# bc: 218  [515](10)|6| 00000000  01111100   124 -> Found adding to stream - 124 bytearray(b'|')
# 445 23
# 445 258
# 445 259
# 445 260
# 445 266
# 445 267
# 445 268
# 445 269
# 445 270
# 445 278
# 445 284
# 445 311
# 445 312
# 445 313
# 445 316
# 445 319
# 445 325
# 445 348
# 445 392
# 445 409
# 445 410
# 445 416
# 445 433
# 445 447
# 445 443
# 445 None
# bc: 217  [516](10)|0| 00000001  00001110   270 -> Found adding to stream - 270 bytearray(b'||')
# 124 23
# 124 258
# 124 176
# 124 132
# 124 124
# bc: 215  [517](10)|2| 00000001  10110111   439 -> Found adding to stream - 439 bytearray(b'\x18\x18')
# 270 23
# 270 258
# 270 259
# 270 260
# 270 266
# 270 267
# 270 268
# 270 269
# 270 270
# bc: 214  [518](10)|4| 00000001  10011011   411 -> Found adding to stream - 411 bytearray(b'\x18\x18')
# 439 23
# 439 258
# 439 259
# 439 260
# 439 266
# 439 267
# 439 268
# 439 269
# 439 270
# 439 278
# 439 284
# 439 311
# 439 312
# 439 313
# 439 316
# 439 319
# 439 325
# 439 348
# 439 392
# 439 409
# 439 410
# 439 416
# 439 433
# 439 447
# 439 443
# 439 None
# bc: 213  [519](10)|6| 00000001  00001111   271 -> Found adding to stream - 271 bytearray(b'||')
# 411 23
# 411 258
# 411 259
# 411 260
# 411 266
# 411 267
# 411 268
# 411 269
# 411 270
# 411 278
# 411 284
# 411 311
# 411 312
# 411 313
# 411 316
# 411 319
# 411 325
# 411 348
# 411 392
# 411 409
# 411 410
# 411 416
# 411 None
# bc: 212  [520](10)|0| 00000001  10011101   413 -> Found adding to stream - 413 bytearray(b'||')
# 271 23
# 271 258
# 271 259
# 271 260
# 271 266
# 271 267
# 271 268
# 271 269
# 271 270
# 271 278
# 271 276
# 271 273
# 271 271
# bc: 210  [521](10)|2| 00000001  01011111   351 -> Found adding to stream - 351 bytearray(b'\x0c\x0c')
# 413 23
# 413 258
# 413 259
# 413 260
# 413 266
# 413 267
# 413 268
# 413 269
# 413 270
# 413 278
# 413 284
# 413 311
# 413 312
# 413 313
# 413 316
# 413 319
# 413 325
# 413 348
# 413 392
# 413 409
# 413 410
# 413 416
# 413 411
# 413 None
# bc: 209  [522](10)|4| 00000001  10100010   418 -> Found adding to stream - 418 bytearray(b'||')
# 351 23
# 351 258
# 351 259
# 351 260
# 351 266
# 351 267
# 351 268
# 351 269
# 351 270
# 351 278
# 351 284
# 351 311
# 351 312
# 351 313
# 351 316
# 351 319
# 351 325
# 351 348
# 351 392
# 351 356
# 351 351
# ...
# 45 23
# 45 258
# 45 176
# 45 132
# 45 124
# 45 68
# 45 24
# 45 44
# 45 49
# 45 45
# bc: 67  [840](10)|0| 00000001  01011010   346 -> Found adding to stream - 346 bytearray(b"\'\'")
# 332 23
# 332 258
# 332 259
# 332 260
# 332 266
# 332 267
# 332 268
# 332 269
# 332 270
# 332 278
# 332 284
# 332 311
# 332 312
# 332 313
# 332 316
# 332 319
# 332 325
# 332 348
# 332 329
# 332 330
# 332 332
# bc: 65  [841](10)|2| 00000001  01011010   346 -> Found adding to stream - 346 bytearray(b"\'\'")
# 346 23
# 346 258
# 346 259
# 346 260
# 346 266
# 346 267
# 346 268
# 346 269
# 346 270
# 346 278
# 346 284
# 346 311
# 346 312
# 346 313
# 346 316
# 346 319
# 346 325
# 346 348
# 346 329
# 346 330
# 346 332
# 346 341
# 346 343
# 346 346
# bc: 64  [842](10)|4| 00000010  00111101   573 -> Found adding to stream - 573 bytearray(b'\x0c\x0c')
# 346 23
# 346 258
# 346 259
# 346 260
# 346 266
# 346 267
# 346 268
# 346 269
# 346 270
# 346 278
# 346 284
# 346 311
# 346 312
# 346 313
# 346 316
# 346 319
# 346 325
# 346 348
# 346 329
# 346 330
# 346 332
# 346 341
# 346 343
# 346 346
# bc: 63  [843](10)|6| 00000010  01010101   597 -> Found adding to stream - 597 bytearray(b'BB')
# 573 23
# 573 258
# 573 259
# 573 260
# 573 266
# 573 267
# 573 268
# 573 269
# 573 270
# 573 278
# 573 284
# 573 311
# 573 312
# 573 313
# 573 316
# 573 319
# 573 325
# 573 348
# 573 392
# 573 409
# 573 410
# 573 416
# 573 433
# 573 447
# 573 454
# 573 455
# 573 507
# 573 529
# 573 544
# 573 554
# 573 573
# bc: 62  [844](10)|0| 00000000  01110100   116 -> Found adding to stream - 116 bytearray(b't')
# 597 23
# 597 258
# 597 259
# 597 260
# 597 266
# 597 267
# 597 268
# 597 269
# 597 270
# 597 278
# 597 284
# 597 311
# 597 312
# 597 313
# 597 316
# 597 319
# 597 325
# 597 348
# 597 392
# 597 409
# 597 410
# 597 416
# 597 433
# 597 447
# 597 454
# 597 455
# 597 507
# 597 529
# 597 544
# 597 554
# 597 573
# 597 617
# 597 607
# 597 604
# 597 578
# 597 580
# 597 596
# 597 598
# 597 None
# bc: 60  [845](10)|2| 00000001  10101110   430 -> Found adding to stream - 430 bytearray(b'dd')
# 116 23
# 116 258
# 116 176
# 116 132
# 116 124
# 116 68
# 116 81
# 116 123
# 116 122
# 116 92
# 116 105
# 116 106
# 116 116
# bc: 59  [846](10)|4| 00000011  00101011   811 -> Found adding to stream - 811 bytearray(b'\x97\x97')
# 430 23
# 430 258
# 430 259
# 430 260
# 430 266
# 430 267
# 430 268
# 430 269
# 430 270
# 430 278
# 430 284
# 430 311
# 430 312
# 430 313
# 430 316
# 430 319
# 430 325
# 430 348
# 430 392
# 430 409
# 430 410
# 430 416
# 430 433
# 430 425
# 430 431
# 430 429
# 430 None
# bc: 58  [847](10)|6| 00000000  00001110   14 -> Found adding to stream - 14 bytearray(b'\x0e')
# 811 23
# 811 258
# 811 259
# 811 260
# 811 266
# 811 267
# 811 268
# 811 269
# 811 270
# 811 278
# 811 284
# 811 311
# 811 312
# 811 313
# 811 316
# 811 319
# 811 325
# 811 348
# 811 392
# 811 409
# 811 410
# 811 416
# 811 433
# 811 447
# 811 454
# 811 455
# 811 507
# 811 529
# 811 544
# 811 554
# 811 573
# 811 617
# 811 656
# 811 683
# 811 686
# 811 691
# 811 734
# 811 736
# 811 779
# 811 819
# 811 799
# 811 802
# 811 None
# bc: 57  [848](10)|0| 00000000  00010010   18 -> Found adding to stream - 18 bytearray(b'\x12')
# 14 23
# 14 8
# 14 17
# 14 12
# 14 15
# 14 14
# bc: 55  [849](10)|2| 00000000  00001111   15 -> Found adding to stream - 15 bytearray(b'\x0f')
# 18 23
# 18 8
# 18 17
# 18 18
# bc: 54  [850](10)|4| 00000001  01110000   368 -> Found adding to stream - 368 bytearray(b'11')
# 15 23
# 15 8
# 15 17
# 15 12
# 15 15
# bc: 53  [851](10)|6| 00000010  01110111   631 -> Found adding to stream - 631 bytearray(b'\x18\x18')
# 368 23
# 368 258
# 368 259
# 368 260
# 368 266
# 368 267
# 368 268
# 368 269
# 368 270
# 368 278
# 368 284
# 368 311
# 368 312
# 368 313
# 368 316
# 368 319
# 368 325
# 368 348
# 368 392
# 368 356
# 368 377
# 368 366
# 368 367
# 368 376
# 368 None
# bc: 52  [852](10)|0| 00000001  11100111   487 -> Found adding to stream - 487 bytearray(b'\x0f\x0f')
# 631 23
# 631 258
# 631 259
# 631 260
# 631 266
# 631 267
# 631 268
# 631 269
# 631 270
# 631 278
# 631 284
# 631 311
# 631 312
# 631 313
# 631 316
# 631 319
# 631 325
# 631 348
# 631 392
# 631 409
# 631 410
# 631 416
# 631 433
# 631 447
# 631 454
# 631 455
# 631 507
# 631 529
# 631 544
# 631 554
# 631 573
# 631 617
# 631 656
# 631 618
# 631 649
# 631 625
# 631 631
# bc: 50  [853](10)|2| 00000000  10111000   184 -> Found adding to stream - 184 bytearray(b'\xb8')
# 487 23
# 487 258
# 487 259
# 487 260
# 487 266
# 487 267
# 487 268
# 487 269
# 487 270
# 487 278
# 487 284
# 487 311
# 487 312
# 487 313
# 487 316
# 487 319
# 487 325
# 487 348
# 487 392
# 487 409
# 487 410
# 487 416
# 487 433
# 487 447
# 487 454
# 487 455
# 487 507
# 487 462
# 487 463
# 487 468
# 487 470
# 487 483
# 487 494
# 487 485
# 487 486
# 487 None
# bc: 49  [854](10)|4| 00000010  10101010   682 -> Found adding to stream - 682 bytearray(b'\x93\x93')
# 184 23
# 184 258
# 184 176
# 184 233
# 184 181
# 184 232
# 184 229
# 184 191
# 184 184
# bc: 48  [855](10)|6| 00000010  11101111   751 -> Found adding to stream - 751 bytearray(b'\x18\x18')
# 682 23
# 682 258
# 682 259
# 682 260
# 682 266
# 682 267
# 682 268
# 682 269
# 682 270
# 682 278
# 682 284
# 682 311
# 682 312
# 682 313
# 682 316
# 682 319
# 682 325
# 682 348
# 682 392
# 682 409
# 682 410
# 682 416
# 682 433
# 682 447
# 682 454
# 682 455
# 682 507
# 682 529
# 682 544
# 682 554
# 682 573
# 682 617
# 682 656
# 682 683
# 682 678
# 682 None
# bc: 47  [856](10)|0| 00000011  00111010   826 -> Found adding to stream - 826 bytearray(b'BB')
# 751 23
# 751 258
# 751 259
# 751 260
# 751 266
# 751 267
# 751 268
# 751 269
# 751 270
# 751 278
# 751 284
# 751 311
# 751 312
# 751 313
# 751 316
# 751 319
# 751 325
# 751 348
# 751 392
# 751 409
# 751 410
# 751 416
# 751 433
# 751 447
# 751 454
# 751 455
# 751 507
# 751 529
# 751 544
# 751 554
# 751 573
# 751 617
# 751 656
# 751 683
# 751 686
# 751 691
# 751 734
# 751 736
# 751 779
# 751 746
# 751 None
# bc: 45  [857](10)|2| 00000001  01011111   351 -> Found adding to stream - 351 bytearray(b'\x0c\x0c')
# 826 23
# 826 258
# 826 259
# 826 260
# 826 266
# 826 267
# 826 268
# 826 269
# 826 270
# 826 278
# 826 284
# 826 311
# 826 312
# 826 313
# 826 316
# 826 319
# 826 325
# 826 348
# 826 392
# 826 409
# 826 410
# 826 416
# 826 433
# 826 447
# 826 454
# 826 455
# 826 507
# 826 529
# 826 544
# 826 554
# 826 573
# 826 617
# 826 656
# 826 683
# 826 686
# 826 691
# 826 734
# 826 736
# 826 779
# 826 819
# 826 None
# bc: 44  [858](10)|4| 00000000  00001010   10 -> Found adding to stream - 10 bytearray(b'\n')
# 351 23
# 351 258
# 351 259
# 351 260
# 351 266
# 351 267
# 351 268
# 351 269
# 351 270
# 351 278
# 351 284
# 351 311
# 351 312
# 351 313
# 351 316
# 351 319
# 351 325
# 351 348
# 351 392
# 351 356
# 351 351
# bc: 43  [859](10)|6| 00000000  00011000   24 -> Found adding to stream - 24 bytearray(b'\x18')
# 10 23
# 10 8
# 10 17
# 10 12
# 10 9
# 10 11
# 10 10
# bc: 42  [860](10)|0| 00000011  00000111   775 -> Found adding to stream - 775 bytearray(b'BB')
# 24 23
# 24 258
# 24 176
# 24 132
# 24 124
# 24 68
# 24 24
# bc: 40  [861](10)|2| 00000000  00010001   17 -> Found adding to stream - 17 bytearray(b'\x11')
# 775 23
# 775 258
# 775 259
# 775 260
# 775 266
# 775 267
# 775 268
# 775 269
# 775 270
# 775 278
# 775 284
# 775 311
# 775 312
# 775 313
# 775 316
# 775 319
# 775 325
# 775 348
# 775 392
# 775 409
# 775 410
# 775 416
# 775 433
# 775 447
# 775 454
# 775 455
# 775 507
# 775 529
# 775 544
# 775 554
# 775 573
# 775 617
# 775 656
# 775 683
# 775 686
# 775 691
# 775 734
# 775 736
# 775 779
# 775 746
# 775 751
# 775 None
# bc: 39  [862](10)|4| 00000000  01101010   106 -> Found adding to stream - 106 bytearray(b'j')
# 17 23
# 17 8
# 17 17
# bc: 38  [863](10)|6| 00000000  11101001   233 -> Found adding to stream - 233 bytearray(b'\xe9')
# 106 23
# 106 258
# 106 176
# 106 132
# 106 124
# 106 68
# 106 81
# 106 123
# 106 122
# 106 92
# 106 105
# 106 106
# bc: 37  [864](10)|0| 00000000  01010110   86 -> Found adding to stream - 86 bytearray(b'V')
# 233 23
# 233 258
# 233 176
# 233 233
# bc: 35  [865](10)|2| 00000000  01010100   84 -> Found adding to stream - 84 bytearray(b'T')
# 86 23
# 86 258
# 86 176
# 86 132
# 86 124
# 86 68
# 86 81
# 86 123
# 86 122
# 86 92
# 86 86
# bc: 34  [866](10)|4| 00000001  10101110   430 -> Found adding to stream - 430 bytearray(b'\x97\x97')
# 84 23
# 84 258
# 84 176
# 84 132
# 84 124
# 84 68
# 84 81
# 84 123
# 84 122
# 84 92
# 84 86
# 84 84
# bc: 33  [867](10)|6| 00000000  00011110   30 -> Found adding to stream - 30 bytearray(b'\x1e')
# 430 23
# 430 258
# 430 259
# 430 260
# 430 266
# 430 267
# 430 268
# 430 269
# 430 270
# 430 278
# 430 284
# 430 311
# 430 312
# 430 313
# 430 316
# 430 319
# 430 325
# 430 348
# 430 392
# 430 409
# 430 410
# 430 416
# 430 433
# 430 425
# 430 431
# 430 429
# 430 430
# bc: 32  [868](10)|0| 00000010  10111000   696 -> Found adding to stream - 696 bytearray(b'\x17\x17')
# 30 23
# 30 258
# 30 176
# 30 132
# 30 124
# 30 68
# 30 24
# 30 44
# 30 39
# 30 30
# bc: 30  [869](10)|2| 00000011  00010000   784 -> Found adding to stream - 784 bytearray(b'\x18\x18')
# 696 23
# 696 258
# 696 259
# 696 260
# 696 266
# 696 267
# 696 268
# 696 269
# 696 270
# 696 278
# 696 284
# 696 311
# 696 312
# 696 313
# 696 316
# 696 319
# 696 325
# 696 348
# 696 392
# 696 409
# 696 410
# 696 416
# 696 433
# 696 447
# 696 454
# 696 455
# 696 507
# 696 529
# 696 544
# 696 554
# 696 573
# 696 617
# 696 656
# 696 683
# 696 686
# 696 691
# 696 734
# 696 698
# 696 None
# bc: 29  [870](10)|4| 00000001  00001100   268 -> Found adding to stream - 268 bytearray(b'\x84\x84')
# 784 23
# 784 258
# 784 259
# 784 260
# 784 266
# 784 267
# 784 268
# 784 269
# 784 270
# 784 278
# 784 284
# 784 311
# 784 312
# 784 313
# 784 316
# 784 319
# 784 325
# 784 348
# 784 392
# 784 409
# 784 410
# 784 416
# 784 433
# 784 447
# 784 454
# 784 455
# 784 507
# 784 529
# 784 544
# 784 554
# 784 573
# 784 617
# 784 656
# 784 683
# 784 686
# 784 691
# 784 734
# 784 736
# 784 779
# 784 819
# 784 799
# 784 798
# 784 None
# bc: 28  [871](10)|6| 00000001  00010010   274 -> Found adding to stream - 274 bytearray(b'\xa7\xa7')
# 268 23
# 268 258
# 268 259
# 268 260
# 268 266
# 268 267
# 268 268
# bc: 27  [872](10)|0| 00000001  11001111   463 -> Found adding to stream - 463 bytearray(b',,')
# 274 23
# 274 258
# 274 259
# 274 260
# 274 266
# 274 267
# 274 268
# 274 269
# 274 270
# 274 278
# 274 276
# 274 273
# 274 274
# bc: 25  [873](10)|2| 00000001  00100100   292 -> Found adding to stream - 292 bytearray(b'||')
# 463 23
# 463 258
# 463 259
# 463 260
# 463 266
# 463 267
# 463 268
# 463 269
# 463 270
# 463 278
# 463 284
# 463 311
# 463 312
# 463 313
# 463 316
# 463 319
# 463 325
# 463 348
# 463 392
# 463 409
# 463 410
# 463 416
# 463 433
# 463 447
# 463 454
# 463 455
# 463 507
# 463 462
# 463 463
# bc: 24  [874](10)|4| 00000011  00100010   802 -> Found adding to stream - 802 bytearray(b'\x0e\x0e')
# 292 23
# 292 258
# 292 259
# 292 260
# 292 266
# 292 267
# 292 268
# 292 269
# 292 270
# 292 278
# 292 284
# 292 311
# 292 291
# 292 292
# bc: 23  [875](10)|6| 00000011  00010100   788 -> Found adding to stream - 788 bytearray(b'\x84\x84')
# 802 23
# 802 258
# 802 259
# 802 260
# 802 266
# 802 267
# 802 268
# 802 269
# 802 270
# 802 278
# 802 284
# 802 311
# 802 312
# 802 313
# 802 316
# 802 319
# 802 325
# 802 348
# 802 392
# 802 409
# 802 410
# 802 416
# 802 433
# 802 447
# 802 454
# 802 455
# 802 507
# 802 529
# 802 544
# 802 554
# 802 573
# 802 617
# 802 656
# 802 683
# 802 686
# 802 691
# 802 734
# 802 736
# 802 779
# 802 819
# 802 799
# 802 802
# bc: 22  [876](10)|0| 00000001  10111011   443 -> Found adding to stream - 443 bytearray(b'||')
# 788 23
# 788 258
# 788 259
# 788 260
# 788 266
# 788 267
# 788 268
# 788 269
# 788 270
# 788 278
# 788 284
# 788 311
# 788 312
# 788 313
# 788 316
# 788 319
# 788 325
# 788 348
# 788 392
# 788 409
# 788 410
# 788 416
# 788 433
# 788 447
# 788 454
# 788 455
# 788 507
# 788 529
# 788 544
# 788 554
# 788 573
# 788 617
# 788 656
# 788 683
# 788 686
# 788 691
# 788 734
# 788 736
# 788 779
# 788 819
# 788 799
# 788 798
# 788 784
# 788 None
# bc: 20  [877](10)|2| 00000011  00011001   793 -> Found adding to stream - 793 bytearray(b'||')
# 443 23
# 443 258
# 443 259
# 443 260
# 443 266
# 443 267
# 443 268
# 443 269
# 443 270
# 443 278
# 443 284
# 443 311
# 443 312
# 443 313
# 443 316
# 443 319
# 443 325
# 443 348
# 443 392
# 443 409
# 443 410
# 443 416
# 443 433
# 443 447
# 443 443
# bc: 19  [878](10)|4| 00000001  00001110   270 -> Found adding to stream - 270 bytearray(b'||')
# 793 23
# 793 258
# 793 259
# 793 260
# 793 266
# 793 267
# 793 268
# 793 269
# 793 270
# 793 278
# 793 284
# 793 311
# 793 312
# 793 313
# 793 316
# 793 319
# 793 325
# 793 348
# 793 392
# 793 409
# 793 410
# 793 416
# 793 433
# 793 447
# 793 454
# 793 455
# 793 507
# 793 529
# 793 544
# 793 554
# 793 573
# 793 617
# 793 656
# 793 683
# 793 686
# 793 691
# 793 734
# 793 736
# 793 779
# 793 819
# 793 799
# 793 798
# 793 784
# 793 788
# 793 None
# bc: 18  [879](10)|6| 00000000  10000100   132 -> Found adding to stream - 132 bytearray(b'\x84')
# 270 23
# 270 258
# 270 259
# 270 260
# 270 266
# 270 267
# 270 268
# 270 269
# 270 270
# bc: 17  [880](10)|0| 00000000  01000100   68 -> Found adding to stream - 68 bytearray(b'D')
# 132 23
# 132 258
# 132 176
# 132 132
# bc: 15  [881](10)|2| 00000001  10100011   419 -> Found adding to stream - 419 bytearray(b'\x18\x18')
# 68 23
# 68 258
# 68 176
# 68 132
# 68 124
# 68 68
# bc: 14  [882](10)|4| 00000010  10001000   648 -> Found adding to stream - 648 bytearray(b'\x18\x18')
# 419 23
# 419 258
# 419 259
# 419 260
# 419 266
# 419 267
# 419 268
# 419 269
# 419 270
# 419 278
# 419 284
# 419 311
# 419 312
# 419 313
# 419 316
# 419 319
# 419 325
# 419 348
# 419 392
# 419 409
# 419 410
# 419 416
# 419 433
# 419 425
# 419 418
# 419 420
# 419 None
# bc: 13  [883](10)|6| 00000011  00111011   827 -> Found adding to stream - 827 bytearray(b'\x0c\x0c')
# 648 23
# 648 258
# 648 259
# 648 260
# 648 266
# 648 267
# 648 268
# 648 269
# 648 270
# 648 278
# 648 284
# 648 311
# 648 312
# 648 313
# 648 316
# 648 319
# 648 325
# 648 348
# 648 392
# 648 409
# 648 410
# 648 416
# 648 433
# 648 447
# 648 454
# 648 455
# 648 507
# 648 529
# 648 544
# 648 554
# 648 573
# 648 617
# 648 656
# 648 618
# 648 649
# 648 625
# 648 631
# 648 643
# 648 None
# bc: 12  [884](10)|0| 00000011  00100000   800 -> Found adding to stream - 800 bytearray(b'\x97\x97')
# 827 23
# 827 258
# 827 259
# 827 260
# 827 266
# 827 267
# 827 268
# 827 269
# 827 270
# 827 278
# 827 284
# 827 311
# 827 312
# 827 313
# 827 316
# 827 319
# 827 325
# 827 348
# 827 392
# 827 409
# 827 410
# 827 416
# 827 433
# 827 447
# 827 454
# 827 455
# 827 507
# 827 529
# 827 544
# 827 554
# 827 573
# 827 617
# 827 656
# 827 683
# 827 686
# 827 691
# 827 734
# 827 736
# 827 779
# 827 819
# 827 826
# 827 None
# bc: 10  [885](10)|2| 00000001  01001101   333 -> Found adding to stream - 333 bytearray(b'11')
# 800 23
# 800 258
# 800 259
# 800 260
# 800 266
# 800 267
# 800 268
# 800 269
# 800 270
# 800 278
# 800 284
# 800 311
# 800 312
# 800 313
# 800 316
# 800 319
# 800 325
# 800 348
# 800 392
# 800 409
# 800 410
# 800 416
# 800 433
# 800 447
# 800 454
# 800 455
# 800 507
# 800 529
# 800 544
# 800 554
# 800 573
# 800 617
# 800 656
# 800 683
# 800 686
# 800 691
# 800 734
# 800 736
# 800 779
# 800 819
# 800 799
# 800 802
# 800 None
# bc: 9  [886](10)|4| 00000010  10111110   702 -> Found adding to stream - 702 bytearray(b'\x84\x84')
# 333 23
# 333 258
# 333 259
# 333 260
# 333 266
# 333 267
# 333 268
# 333 269
# 333 270
# 333 278
# 333 284
# 333 311
# 333 312
# 333 313
# 333 316
# 333 319
# 333 325
# 333 348
# 333 329
# 333 330
# 333 332
# 333 341
# 333 336
# 333 334
# 333 333
# bc: 8  [887](10)|6| 00000000  01111100   124 -> Found adding to stream - 124 bytearray(b'|')
# 702 23
# 702 258
# 702 259
# 702 260
# 702 266
# 702 267
# 702 268
# 702 269
# 702 270
# 702 278
# 702 284
# 702 311
# 702 312
# 702 313
# 702 316
# 702 319
# 702 325
# 702 348
# 702 392
# 702 409
# 702 410
# 702 416
# 702 433
# 702 447
# 702 454
# 702 455
# 702 507
# 702 529
# 702
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 TestImage('jake(240x240).bin','jake(240x240)-ColorTable.txt',(240,240),8)
#
# Cell In[70], line 198, in TestImage(ImagePath, ColorTablePath, frameSize, min_code)
#     194 ColorTable = newColorTable
#     196 src = open(ImagePath, "rb")
# --> 198 decompressed = lzw_Decompress(src,min_code)
#     199 src.close()
#     200 # Create a blank white RGB image
#
# Cell In[70], line 163, in lzw_Decompress(src, LZW_Min_Code)
#     158     print('Not Found adding to stream-',lastCode,bytearray(lastcodearr) + bytearray([K]))
#     160 #codeTable[newTableIndex] = bytearray(get_CodeValue(lastCode,codeTable,ColorTableLen)) + bytearray([K])
#     161 #codeTable.append((lastCode, bytearray([K])))
#     162 #codeTable.append( (lastCode,K) )
# --> 163 codeTree.append(lastCode,K)
#     164 if newTableIndex >= 2**CodeLen-1:
#     165     print('TableIndex maxed out! ',newTableIndex)
#
# Cell In[70], line 28, in treeNode.append(self, code, byte)
#      26 currentNode = self
#      27 while True:
# ---> 28     print(code,currentNode.index)
#      29     if currentNode.index == code:
#      30         return False
#
# File /usr/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3029, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3027 def write(data, *args, **kwargs):
#    3028     """Write data to both the original destination and the capture dictionary."""
# -> 3029     result = original_write(data, *args, **kwargs)
#    3030     if any(
#    3031         [
#    3032             self.display_pub.is_publishing,
#    (...)   3035         ]
#    3036     ):
#    3037         return result
#
# File /usr/lib/python3.13/site-packages/ipykernel/iostream.py:684, in OutStream.write(self, string)
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
# --> 684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#     688     if self._subprocess_flush_pending:
#
# KeyboardInterrupt:

# %%
TestImage('jake_64_colors(240x240).bin','jake_64_colors(240x240)-ColorTable.txt',(240,240),6)
# Out:
# ColorTableLen: 64
# LZW_Min_Code: 6
# bc: 0  [66](7)|0| 01000000  01000000   64 -> Clear Code - Initializing codeTable
# bc: 254  [66](7)|7| 00100000  00100000   32 -> First Code - Appending to indexStream
# bc: 253  [66](7)|6| 01000010  01000010   66 -> Not Found adding to stream- 32 bytearray(b'  ')
# 32 32
# bc: 252  [67](7)|5| 01000011  01000011   67 ->
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 TestImage('jake_64_colors(240x240).bin','jake_64_colors(240x240)-ColorTable.txt',(240,240),6)
#
# Cell In[41], line 199, in TestImage(ImagePath, ColorTablePath, frameSize, min_code)
#     195 ColorTable = newColorTable
#     197 src = open(ImagePath, "rb")
# --> 199 decompressed = lzw_Decompress(src,min_code)
#     200 src.close()
#     201 # Create a blank white RGB image
#
# Cell In[41], line 155, in lzw_Decompress(src, LZW_Min_Code)
#     153     print('Found adding to stream -',K,bytearray(codearr))
#     154 else:
# --> 155     lastcodearr = get_CodeValue(lastCode,codeTree,ColorTableLen)
#     156     K = lastcodearr[0]
#     157     indexStream += bytearray(lastcodearr) + bytearray([K])
#
# Cell In[41], line 58, in get_CodeValue(Code, treeNode, ColorTableLen)
#      56 else:
#      57     newCode = Code
# ---> 58     outList = treeNode.getList(Code,ColorTableLen)
#      59     outList = outList[::-1]
#      60     return bytearray(outList)
#
# Cell In[41], line 11, in treeNode.getList(self, code, numColors)
#       9 currentNode = self
#      10 while True:
# ---> 11     if currentNode.byte < numColors:
#      12         outList = [currentNode.byte]
#      13     if currentNode == None:
#
# AttributeError: 'NoneType' object has no attribute 'byte'

# %%
TestImage('steam_boat_monocrome(128x64).bin','steam_boat_monocrome(128x64)-ColorTable.txt',(128,64),2)
# Out:
# ColorTableLen: 4
# LZW_Min_Code: 2
# CodeTable len:  686
# <PIL.Image.Image image mode=RGB size=128x64>
